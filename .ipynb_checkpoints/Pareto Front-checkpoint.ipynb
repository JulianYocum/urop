# %%
import time
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = 'serif'
plt.rcParams["font.serif"] = 'Times'
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["axes.labelsize"] = 16
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams["ytick.labelsize"] = 14
plt.rcParams["legend.fontsize"] = 12
plt.rcParams["mathtext.rm"] = "serif"
plt.rcParams["mathtext.it"] = "serif:italic"
plt.rcParams["mathtext.bf"] = "serif:bold"
plt.rcParams["mathtext.fontset"] = "custom"
#plt.rcParams['text.usetex'] = True
import numpy as np

from DataAnalysis import DataAnalysis
#%run new_DataAnalysis.ipynb|
from MonteCarlo import MonteCarlo
from Helper import *

# %%
# data = DataAnalysis()
# data.load_eventdf('data/new_moo/8-5/events.csv')
# data.load_clusterdf('data/new_moo/8-5/clusters.csv')
# data.filter_fit(3.5, 5) #(NRMSE, channels)
# data.get_cluster(0)

# %%
# rand_times = np.sort(np.random.choice(np.arange(1000),10,replace=False, dtype=np.float64))
# rand_times[0]

# %%
# mc = MonteCarlo(num_tracks=10, track_type="sasso", particle_type="muon")
# mc.filter_fit(100, 3)
# #mc.get_eventdf()
# mc.save_eventdf("./data/mc_eventdf.csv")
# mc.save_clusterdf("./data/mc_clusterdf.csv")

# mc = DataAnalysis()
# mc.load_eventdf('data/new_moo/3-30/MC_events.csv')
# mc.load_clusterdf('data/new_moo/3-30/MC_clusters.csv')

mc = DataAnalysis()
mc.load_eventdf("./data/mc_eventdf.csv")
mc.load_clusterdf("./data/mc_clusterdf.csv")

# %%
mc.get_clusterdf()
# Out:
#    Cluster  Events  Channels  StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0       9         9    13897.2        0.08  0.879307  0.136408
# 1        1       6         6    23858.2        0.05  0.793982  0.356439
# 2        2       9         9    53906.2        0.08  1.040519  0.707006
# 3        4       3         3    55653.2        0.02  1.592943  0.600279
# 4        5       4         4    77847.2        0.03  1.736127  1.130017
# 5        6       7         7    86160.2        0.06  1.058164  0.762670
# 6        7      15        15    90145.2        0.14  1.014879  0.849854
# 7        8       8         8    93003.2        0.07  0.945134  0.451119
#
#     Azimuth  ExtraCh  MissingCh  Likelihood  \
# 0 -0.320063        0          0  -20.899590
# 1 -0.906506        0          0  -20.030921
# 2  0.253665        0          0  -25.686371
# 3 -0.327657        0          0  -11.703394
# 4 -0.602930        0          0  -12.036961
# 5 -0.759076        0          0  -17.914687
# 6  0.004274        0          0  -36.964037
# 7  1.165235        0          0  -18.160754
#
#                                              Fitline
# 0  [41.864033, -270.644245, -43.799564, -0.129402...
# 1  [320.635577, 168.382981, 121.00475, -0.335923,...
# 2  [-18.589051, 32.412426, -280.951662, -0.41077,...
# 3  [251.575017, 137.623889, 347.911921, -0.538828...
# 4  [-244.676065, -80.758049, 57.194602, -0.904024...
# 5  [-212.831318, 306.666965, -243.009934, 0.68532...
# 6  [-311.520047, -73.113935, 140.811866, -0.60396...
# 7  [28.232441, -102.364928, -200.628746, 0.098095...

# %%
# from pymoo.visualization.scatter import Scatter
# test = DataAnalysis()
# line, pre_result, fin_result = test.fitline(mc.get_cluster(0), pop_num=50, gen_num=50)

# %%
# plot = Scatter(title = "Objective Space", angle=(0,45))
# plot.add(pre_result.F)
# plot.show()

# %%
# plot = Scatter(title = "Objective Space", angle=(0,45))
# plot.add(fin_result.F[:,:2])
# plot.show()

# %%
# ## generate data
# test = DataAnalysis()
# start = time.time()
# #test.set_eventdf(mc.get_cluster(range(1)))
# test.set_eventdf(mc.get_eventdf())

# #test.arrange_clusters(3, 1.0) # >= 5 events, <= 1.0 seconds
# test.make_clusterdf(pop_num=1000, gen_num=200, verbose=True, save_pareto=True)

# print("here")
# test.save_eventdf("./data/test_eventdf.csv")
# test.save_clusterdf("./data/test_clusterdf.csv")
# test.save_paretoX("./data/test_paretoX.csv")
# test.save_paretoF("./data/test_paretoF.csv")
# time.time() - start

## load data
test = DataAnalysis()
test.load_eventdf("./data/test_eventdf.csv")
test.load_clusterdf("./data/test_clusterdf.csv")
test.load_paretoX("./data/test_paretoX.csv")
test.load_paretoF("./data/test_paretoF.csv")

# %%
test.get_clusterdf()
# Out:
#    Cluster  Events  Channels  StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0       9         9    13897.2        0.08  0.700124  0.132377
# 1        1       6         6    23858.2        0.05  0.741294  0.370808
# 2        2       9         9    53906.2        0.08  0.991418  0.724754
# 3        4       3         3    55653.2        0.02  1.317736  0.546265
# 4        5       4         4    77847.2        0.03  1.534654  1.121311
# 5        6       7         7    86160.2        0.06  0.889009  0.822071
# 6        7      15        15    90145.2        0.14  1.000160  0.861524
# 7        8       8         8    93003.2        0.07  0.858929  0.451556
#
#     Azimuth  ExtraCh  MissingCh  Likelihood  \
# 0 -0.804302        0          0  -20.478524
# 1 -0.641302        0          0  -15.538419
# 2  0.264348        0          0  -39.447502
# 3  0.441696        0          0   -5.088073
# 4 -0.567215        4          0  -12.987388
# 5 -0.761393        1          0  -39.449618
# 6  0.002924        0          0  -60.997714
# 7  1.070399        2          0  -23.995253
#
#                                              Fitline
# 0  [39.306278, -269.796531, -23.039099, -0.130048...
# 1  [257.690607, 176.274577, 292.752459, 0.362355,...
# 2  [-32.536953, 14.500891, -247.133318, 0.413728,...
# 3  [275.661357, 124.257424, 363.094013, 0.247507,...
# 4  [194.778423, -60.753096, -151.495055, -0.89875...
# 5  [194.279516, 239.673879, 174.739837, -0.726481...
# 6  [24.517275, 175.661403, -221.73263, -0.610723,...
# 7  [19.665921, -33.696181, -344.106474, 0.057481,...

# %%
plt.figure(figsize=(5,5))
plt.title("Pathlengths")
plt.scatter( np.array(mc.get_eventdf()['PathLength']), np.array(test.get_eventdf()['PathLength']), s=5)
plt.ylabel("mm (reconstructed)")
plt.xlabel("mm (generated)")
plt.xlim(0,80)
plt.ylim(0,80)
# Out:
# (0.0, 80.0)

# %%
test.get_eventdf()
# Out:
#     Run  Channel      Time  NumPulses  OFdelay  MaxPosInWindow  \
# 0     0      577  13894.00          1      3.2             3.2
# 1     0      578  13894.01          1      3.2             3.2
# 2     0      579  13894.02          1      3.2             3.2
# 3     0      580  13894.03          1      3.2             3.2
# 4     0      581  13894.04          1      3.2             3.2
# ..  ...      ...       ...        ...      ...             ...
# 56    0      784  93000.03          1      3.2             3.2
# 57    0      785  93000.04          1      3.2             3.2
# 58    0      824  93000.05          1      3.2             3.2
# 59    0      825  93000.06          1      3.2             3.2
# 60    0      826  93000.07          1      3.2             3.2
#
#     SelectedEnergy  Baseline  MaxToBaseline  StabAmp  IsSaturated  Track  \
# 0     46110.053455       0.0            0.0      0.0        False      0
# 1     42051.088773       0.0            0.0      0.0        False      0
# 2     33539.852903       0.0            0.0      0.0        False      0
# 3     40080.634626       0.0            0.0      0.0        False      0
# 4     45452.790661       0.0            0.0      0.0        False      0
# ..             ...       ...            ...      ...          ...    ...
# 56    46281.443661       0.0            0.0      0.0        False      9
# 57    21566.024496       0.0            0.0      0.0        False      9
# 58     5152.010409       0.0            0.0      0.0        False      9
# 59    52967.558970       0.0            0.0      0.0        False      9
# 60    34301.380929       0.0            0.0      0.0        False      9
#
#      MaxTime  Cluster   Hit  PathLength         dEdx
# 0   13897.20        0  True   49.808806   925.740999
# 1   13897.21        0  True   50.441315   833.663609
# 2   13897.22        0  True   50.441315   664.928201
# 3   13897.23        0  True   50.441315   794.599319
# 4   13897.24        0  True   50.441315   901.102411
# ..       ...      ...   ...         ...          ...
# 56  93003.23        8  True   55.569817   832.852194
# 57  93003.24        8  True   26.031684   828.452925
# 58  93003.25        8  True    9.194323   560.346890
# 59  93003.26        8  True   55.569817   953.171383
# 60  93003.27        8  True   33.043347  1038.072237
#
# [61 rows x 17 columns]

# %%
plt.title("Pareto Front N=211")
plt.xlabel("log-likelihood")
plt.ylabel("count")
array = plt.hist(test.paretoF[0][:,2], np.linspace(0,70,30),histtype='step')

# %%
mc.get_clusterdf(False)
# Out:
#    Cluster  Events  Channels  StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0       9         9    13897.2        0.08  0.879307  0.136408
# 1        1       6         6    23858.2        0.05  0.793982  0.356439
# 2        2       9         9    53906.2        0.08  1.040519  0.707006
# 3        4       3         3    55653.2        0.02  1.592943  0.600279
# 4        5       4         4    77847.2        0.03  1.736127  1.130017
# 5        6       7         7    86160.2        0.06  1.058164  0.762670
# 6        7      15        15    90145.2        0.14  1.014879  0.849854
# 7        8       8         8    93003.2        0.07  0.945134  0.451119
#
#     Azimuth  ExtraCh  MissingCh  Likelihood
# 0 -0.320063        0          0  -20.899590
# 1 -0.906506        0          0  -20.030921
# 2  0.253665        0          0  -25.686371
# 3 -0.327657        0          0  -11.703394
# 4 -0.602930        0          0  -12.036961
# 5 -0.759076        0          0  -17.914687
# 6  0.004274        0          0  -36.964037
# 7  1.165235        0          0  -18.160754

# %%
test.get_clusterdf(False)
# Out:
#    Cluster  Events  Channels  StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0       9         9    13897.2        0.08  0.700124  0.132377
# 1        1       6         6    23858.2        0.05  0.741294  0.370808
# 2        2       9         9    53906.2        0.08  0.991418  0.724754
# 3        4       3         3    55653.2        0.02  1.317736  0.546265
# 4        5       4         4    77847.2        0.03  1.534654  1.121311
# 5        6       7         7    86160.2        0.06  0.889009  0.822071
# 6        7      15        15    90145.2        0.14  1.000160  0.861524
# 7        8       8         8    93003.2        0.07  0.858929  0.451556
#
#     Azimuth  ExtraCh  MissingCh  Likelihood
# 0 -0.804302        0          0  -20.478524
# 1 -0.641302        0          0  -15.538419
# 2  0.264348        0          0  -39.447502
# 3  0.441696        0          0   -5.088073
# 4 -0.567215        4          0  -12.987388
# 5 -0.761393        1          0  -39.449618
# 6  0.002924        0          0  -60.997714
# 7  1.070399        2          0  -23.995253

# %%
channelcollisions(pts_to_line(test.paretoX[0][0]))
CLUSTER = 8
COLORS = {0: 'blue', 1: 'green', 2: 'red'}
#f3 = []

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.tight_layout()
# plt.title("Single Cluster Pareto Front Sample")
# ax1.title.set_text("Single Cluster Pareto Front Sample")
ax1.set_ylabel("- log-likelihood")
ax1.set_xlabel("theta")
# ax2.title.set_text("Single Cluster Pareto Front Sample")
ax2.set_ylabel("- log-likelihood")
ax2.set_xlabel("phi")

zeniths = {0: [], 1: [], 2: []}
azimuths = {0: [], 1: [], 2: []}
f3s = {0: [], 1: [], 2: []}

for i in range(len(test.paretoX[CLUSTER])):
    betterline = pts_to_line(test.paretoX[CLUSTER][i]) #index])
    hit_channels = channelcollisions(betterline, test.coords)[0]
    missed, extra = test.errorchannels(test.get_cluster(CLUSTER), hit_channels)
    
    zenith = test.zenith(betterline)
    azimuth = test.azimuth(betterline)
    f3 = test.paretoF[CLUSTER][i][2]
    
    zeniths[len(missed)].append(zenith)
    azimuths[len(missed)].append(azimuth)
    f3s[len(missed)].append(f3)
    
#     zeniths = {}
#     azimuths = {}
#         #print(missed, extra)
#         zeniths.append(test.zenith(betterline))
#         azimuths.append(test.azimuth(betterline))
#         f3.append(-test.paretoF[CLUSTER][i][2])

for k in range(3):
    array = ax1.scatter(zeniths[k], f3s[k], s=5, label=str(k) + " missed")
    array = ax2.scatter(azimuths[k], f3s[k], s=5, label=str(k) + " missed")

plt.legend()
display(mc.get_clusterdf(0)[mc.get_clusterdf(0)['Cluster'] == CLUSTER])
display(test.get_clusterdf(0)[test.get_clusterdf(0)['Cluster'] == CLUSTER])
# Out:
#    Cluster  Events  Channels  StartTime  TimeSpread     NRMSE    Zenith  \
# 7        8       8         8    93003.2        0.07  0.945134  0.451119
#
#     Azimuth  ExtraCh  MissingCh  Likelihood
# 7  1.165235        0          0  -18.160754
#    Cluster  Events  Channels  StartTime  TimeSpread     NRMSE    Zenith  \
# 7        8       8         8    93003.2        0.07  0.858929  0.451556
#
#     Azimuth  ExtraCh  MissingCh  Likelihood
# 7  1.070399        2          0  -23.995253

# %%
test.paretoX[0][0]
# Out:
# array([  39.9647026 , -271.67360114,  -19.45142868,   26.27673755,
#        -267.44481697,   83.72688876])

# %%
test.paretoF[0]
# Out:
# array([[1.37882155e-02, 6.76096685e-04, 1.94097879e+01],
#        [1.17965602e-02, 6.32421371e-04, 3.45667973e+01],
#        [2.33530356e-02, 3.32610828e-04, 3.16214497e+01],
#        ...,
#        [1.43590401e-02, 5.84346264e-04, 2.99988612e+01],
#        [1.65918630e-02, 5.25900386e-04, 2.42641779e+01],
#        [1.91278033e-02, 4.03362732e-04, 3.94647159e+01]])

# %%
plt.title("Single Cluster Pareto Front Sample")
plt.ylabel("log-likelihood")
plt.xlabel("theta")
zeniths = [test.zenith(pts_to_line(test.paretoX[0][i])) for i in range(len(test.paretoX[0]))]
array = plt.scatter(zeniths, -test.paretoF[0][:,2], s=5)

# %%
plt.title("Single Cluster Pareto Front Sample")
plt.ylabel("log-likelihood")
plt.xlabel("phi")
azimuths = [test.azimuth(pts_to_line(test.paretoX[0][i])) for i in range(len(test.paretoX[0]))]
array = plt.scatter(azimuths, -test.paretoF[0][:,2], s=5)

# %%
from Helper import *

dEdx_pdf = make_pdf('./data/pdf/dEdx/bins_dEdx_muon.csv', './data/pdf/dEdx/values_dEdx_muon.csv', domain_range=[0,190])
clusters = np.array(mc.get_clusterdf()['Cluster'])

log_likelihoods_mc = [np.log(dEdx_pdf(np.array(mc.get_cluster(c)['dEdx'])/100)).sum() for c in clusters]
log_likelihoods_test = [np.log(dEdx_pdf(np.array(test.get_cluster(c)['dEdx'])/100)).sum() for c in clusters]


# min_path_test = test.get_eventdf()[test.get_eventdf()['PathLength'] > 30]
# min_path_mc = mc.get_eventdf()[test.get_eventdf()['PathLength'] > 30]

plt.figure(figsize=(12,8))

plt.subplot(2,3,1)
plt.title("dEdx")
#plt.scatter(np.array(mc.get_eventdf()['dEdx'])/100, np.array(test.get_eventdf()['dEdx'])/100, s=5)
plt.scatter(test.get_eventdf()['dEdx']/100, mc.get_eventdf()['dEdx']/100, s=5)
plt.xlabel("MeV/cm (reconstructed)")
plt.ylabel("MeV/cm (generated)")
plt.xlim(4,30)
plt.ylim(4,30)
plt.xscale('log')
plt.yscale('log')

plt.subplot(2,3,2)
plt.title("dEdx log-likelihoods")
plt.scatter(log_likelihoods_mc, log_likelihoods_test, s=5)
plt.xlim(-100,0)
plt.ylim(-100,0)
plt.xlabel("log(likelihood) (generated)")
plt.ylabel("log(likelihood) (reconstructed)")

plt.subplot(2,3,3)
plt.title("Pathlengths")
plt.scatter( np.array(mc.get_eventdf()['PathLength']), np.array(test.get_eventdf()['PathLength']), s=5)
plt.ylabel("mm (reconstructed)")
plt.xlabel("mm (generated)")
plt.xlim(0,80)
plt.ylim(0,80)

plt.subplot(2,3,4)
plt.title("Zenith")
plt.scatter(np.array(mc.get_clusterdf()['Zenith']) * 180 / np.pi, np.array(test.get_clusterdf()['Zenith']) * 180 / np.pi, s=5)
plt.xlabel("degrees (reconstructed)")
plt.ylabel("degrees (generated)")


plt.subplot(2,3,5)
plt.title("Azimuth")
plt.scatter(np.array(mc.get_clusterdf()['Azimuth']) * 180 / np.pi, np.array(test.get_clusterdf()['Azimuth']) * 180 / np.pi, s=5)
plt.xlabel("degrees (reconstructed)")
plt.ylabel("degrees (generated)")

plt.tight_layout()

# %%
test.get_clusterdf(fitline=False)
# Out:
#    Cluster  Events  Channels  StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0       9         9    13897.2        0.08  0.700124  0.132377
# 1        1       6         6    23858.2        0.05  0.741294  0.370808
# 2        2       9         9    53906.2        0.08  0.991418  0.724754
# 3        4       3         3    55653.2        0.02  1.317736  0.546265
# 4        5       4         4    77847.2        0.03  1.534654  1.121311
# 5        6       7         7    86160.2        0.06  0.889009  0.822071
# 6        7      15        15    90145.2        0.14  1.000160  0.861524
# 7        8       8         8    93003.2        0.07  0.858929  0.451556
#
#     Azimuth  ExtraCh  MissingCh  Likelihood
# 0 -0.804302        0          0  -20.478524
# 1 -0.641302        0          0  -15.538419
# 2  0.264348        0          0  -39.447502
# 3  0.441696        0          0   -5.088073
# 4 -0.567215        4          0  -12.987388
# 5 -0.761393        1          0  -39.449618
# 6  0.002924        0          0  -60.997714
# 7  1.070399        2          0  -23.995253

# %%
mc.get_clusterdf(fitline=False)
# Out:
#    Cluster  Events  Channels  StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0       9         9    13897.2        0.08  0.879307  0.136408
# 1        1       6         6    23858.2        0.05  0.793982  0.356439
# 2        2       9         9    53906.2        0.08  1.040519  0.707006
# 3        4       3         3    55653.2        0.02  1.592943  0.600279
# 4        5       4         4    77847.2        0.03  1.736127  1.130017
# 5        6       7         7    86160.2        0.06  1.058164  0.762670
# 6        7      15        15    90145.2        0.14  1.014879  0.849854
# 7        8       8         8    93003.2        0.07  0.945134  0.451119
#
#     Azimuth  ExtraCh  MissingCh  Likelihood
# 0 -0.320063        0          0  -20.899590
# 1 -0.906506        0          0  -20.030921
# 2  0.253665        0          0  -25.686371
# 3 -0.327657        0          0  -11.703394
# 4 -0.602930        0          0  -12.036961
# 5 -0.759076        0          0  -17.914687
# 6  0.004274        0          0  -36.964037
# 7  1.165235        0          0  -18.160754
