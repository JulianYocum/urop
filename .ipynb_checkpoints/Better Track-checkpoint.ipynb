# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(i[0], i[1])
plt.scatter(j[0], j[1])
plt.xlim(0,10)
plt.ylim(-10,10)
# Out:
# (-10.0, 10.0)

# %%
def Sum_xy (c):
    return sum([x*y for x,y in zip(c[0],c[1])])

def Sum_x2 (c):
    return sum([x**2 for x in c[0]])

# %%
m = ((len(i[0]) - len(j[0])) * (Sum_xy(i) - Sum_xy(j)) - (sum(i[0]) - sum(j[0])*(sum(i[1]) - sum(j[1]))))/ \
    ((len(i) - len(j))* (Sum_x2(i) - Sum_x2(j)) - ((sum(i[0]))**2 - (sum(j[0]))**2))
m
# Out:
# 3.95

# %%
b = ((sum(i[1]) - sum(j[1])) - m * (sum(i[0]) - sum(j[0]))) / \
    (len(i[0]) - len(j[0]))
b
# Out:
# -49.3

# %%
# Out:
# 142.00096038415367

# %%
# Out:
# 1.2999999999999599

# %%
xvals = np.arange(-10,10,.1)
yvals = residual(xvals, 0)


plt.plot(xvals, yvals)

xvals[np.where(yvals== min(yvals))[0][0]]
# Out:
# 0.9999999999999609

# %%
def z_function(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))



fig = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_wireframe(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.show()

# %%
A = [[1, 2, 3], [1, 2, 3]]
#j = [[-100,-101,-102], [-100,-101,-102]]
B = ([0, 4, 5], [0, 4, 5])

# %%
def residual (x):
    m = x[0]
    b = x[1]
    #return(sum([(j[1][k] - (m*j[0][k] + b))**2 for k in range(len(j[0]))]))
    return sum([(A[1][k] - (m*A[0][k] + b))**2 for k in range(len(A[0]))]) \
        + 1 / sum([(B[1][k] - (m*B[0][k] + b))**2 for k in range(len(B[0]))])

# %%
x = np.linspace(-10, 10, 10000)
y = np.linspace(-10, 10, 10000)

X, Y = np.meshgrid(x, y)
Z = residual([X, Y])

coords = np.where(Z == np.min(Z))
print(coords)

# why is it flipped??
b = x[coords[0][0]]
m = y[coords[1][0]]


print(m)
print(b)
# Out:
# (array([5380]), array([5296]))
# 0.5930593059305931
# 0.7610761076107604

# %%
x = np.linspace(0, 10, 100)

plt.scatter(A[0], A[1])
plt.scatter(B[0], B[1])

plt.plot(x, m*x+b)

plt.xlim(0,10)
plt.ylim(-1,10)
# Out:
# (-1.0, 10.0)

# %%
A = [[1, 2, 3], [1, 2, 3]]
#j = [[-100,-101,-102], [-100,-101,-102]]
B = ([0, 4, 5], [0, 4, 5])

# %%
def residual (x):
    m = x[0]
    b = x[1]
    #return(sum([(j[1][k] - (m*j[0][k] + b))**2 for k in range(len(j[0]))]))
    return sum([(A[1][k] - (m*A[0][k] + b))**2 for k in range(len(A[0]))]) \
        + 1 / sum([(B[1][k] - (m*B[0][k] + b))**2 for k in range(len(B[0]))])

# %%
m, b = (1,1)
[(A[1][k]) for k in range(len(A[0]))]
# Out:
# [1, 2, 3]

# %%
from scipy import optimize

x = np.ones(2)
for i in range(100):
    #x = np.array([.9, .1])
    #eps = np.sqrt(np.finfo(float).eps)
    eps = np.float(1e-2)
    g = optimize.approx_fprime(x, residual, eps)
    x -= g*eps
print(x)
# Out:
# [0.57685477 0.79894804]

# %%
# Out:
# [-0.87713449  4.87713449] [-0.62211785  4.55545118] [-1.13215113  5.19881779]

# %%
def cross(a, b):
    c = [a[1]*b[2] - a[2]*b[1],
         a[2]*b[0] - a[0]*b[2],
         a[0]*b[1] - a[1]*b[0]]
    return c

# %%
A = [[1, 2, 3], [1.1, 1.9, 2.9], [.9,2.1,3.1]]
#j = [[-100,-101,-102], [-100,-101,-102]]
B = [[0, 4, 5], [.1, 3.9, 5.1], [-.1, 4.1, 4.9]]

# %%
def ptsfromline(pts, linepts):
    
    dlist = []
    
    a = linepts[0]
    b = linepts[1]
    
    for i in range(len(pts[0])):

        p = np.array([pts[0][i], pts[1][i], pts[2][i]])
        d = np.linalg.norm(cross(p-a, p-b)) / np.linalg.norm(b-a)

        dlist.append(d)
    
    return dlist

# x = [p0,p1,p2,v0,v1,v2]
def cost (x): 
    p = x[:3]
    v = x[3:]
    
    linepts = v * np.mgrid[-.5:.5:2j][:, np.newaxis] + p
    
    Alist = ptsfromline(A, linepts)
    Blist = ptsfromline(B, linepts)
    
    #print(Alist)
    #print(Blist)
    
    return sum([d**2 for d in Alist]) + (1/10) * 1 / sum([d**2 for d in Blist])
    
    
    
    #return(sum([(j[1][k] - (m*j[0][k] + b))**2 for k in range(len(j[0]))]))
    return sum([(A[1][k] - (m*A[0][k] + b))**2 for k in range(len(A[0]))]) \
        + 1 / sum([(B[1][k] - (m*B[0][k] + b))**2 for k in range(len(B[0]))])

# %%
data  = np.array(A).T

datamean = data.mean(axis=0)
# Do an SVD on the mean-centered data.
uu, dd, vv = np.linalg.svd(data - datamean)

cost(np.append(vv[0], datamean))
# Out:
# 0.7156219314857024

# %%
linepts = vv[0] * np.mgrid[-5:5:2j][:, np.newaxis] + datamean
print(*linepts.T)


plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')

ax.scatter3D(*A)
ax.scatter3D(*B)

ax.plot3D(*linepts.T)

ax.view_init(25, 35)

#plt.xlim(0,10)
#plt.ylim(-1,10)
# Out:
# [-0.87713449  4.87713449] [-0.62211785  4.55545118] [-1.13215113  5.19881779]

# %%
from scipy import optimize

#x = np.ones(6)
x = np.append(vv[0], datamean)

for i in range(500):
    #x = np.array([.9, .1])
    #eps = np.sqrt(np.finfo(float).eps)
    eps = np.float(1e-2)
    g = optimize.approx_fprime(x, cost, eps)
    x -= g*eps

p = x[:3]
v = x[3:]
linepts = v * np.mgrid[-5:5:2j][:, np.newaxis] + p
linepts
# Out:
# array([[ -9.00667867,  -6.86107919, -10.94044391],
#        [  9.99737083,   8.35133644,  11.48766156]])

# %%
plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')

ax.scatter3D(*A)
ax.scatter3D(*B)

ax.plot3D(*linepts.T)

ax.view_init(15, 85)


plt.xlim(-5,5)
plt.ylim(-5,5)
ax.set_zlim(-5,5)
# Out:
# (-5.0, 5.0)

# %%
# %run MonteCarlo.ipynb
mc = MonteCarlo(5, "box")

# %%
# %run DataAnalysis.ipynb

da1 = DataAnalysis()
da1.set_eventdf(mc.get_eventdf())
da1.arrange_clusters().make_clusterdf()
da1.get_clusterdf()
# Out:
#    Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0      12        12  7.924100e+05         0.0  0.799906  0.781604
# 1        1      10        10  1.988182e+06         0.0  1.022473  1.058378
# 2        2      14        14  1.997571e+06         0.0  0.868092  0.924203
# 3        3       6         6  2.023319e+06         0.0  0.651467  1.366407
# 4        4       8         8  2.602365e+06         0.0  0.848489  1.463333
#
#     Azimuth  ExtraCh  MissingCh
# 0  0.012926        0          1
# 1 -1.370503        2          1
# 2 -0.452301        1          0
# 3  0.000000        0          0
# 4  0.675213        3          0

# %%
# %run DataAnalysis-Copy3.ipynb

da2 = testDataAnalysis()
da2.set_eventdf(mc.get_eventdf())
da2.arrange_clusters()

# %%
da2.make_clusterdf()
da2.get_clusterdf()
# Out:
#    Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0      12        12  7.924100e+05         0.0  0.800167  0.778995
# 1        1      10        10  1.988182e+06         0.0  1.056699  1.078176
# 2        2      14        14  1.997571e+06         0.0  0.874329  0.918557
# 3        3       6         6  2.023319e+06         0.0  0.652278  1.360239
# 4        4       8         8  2.602365e+06         0.0  0.927441  1.484728
#
#         Azimuth  ExtraCh  MissingCh
# 0  1.394002e-02        0          1
# 1 -1.404266e+00        0          1
# 2 -4.634827e-01        1          0
# 3  6.789255e-11        0          0
# 4  6.412881e-01        1          0

# %%
mc.get_clusterdf()
# Out:
#    Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0      12        12  7.924100e+05         0.0  0.881025  0.772491
# 1        1      10        10  1.988182e+06         0.0  1.074111  1.055971
# 2        2      14        14  1.997571e+06         0.0  0.899298  0.906606
# 3        3       6         6  2.023319e+06         0.0  1.011864  1.338762
# 4        4       8         8  2.602365e+06         0.0  0.980412  1.498909
#
#     Azimuth  ExtraCh  MissingCh
# 0  0.075146        0          0
# 1 -1.390983        0          0
# 2 -0.469227        0          0
# 3 -0.000803        0          0
# 4  0.637748        0          0

# %%
da1.show_cluster(4, 15, 65)

# %%
da2.show_cluster(4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1612-65ceb19d3b8b> in <module>
# ----> 1 da2.show_cluster(4)
#
# <ipython-input-1610-afc227cedd22> in show_cluster(self, cluster_list, x1, x2)
#     622             ax.scatter3D(*coords)
#     623
# --> 624             line = self.fitline(cluster)
#     625             ax.plot3D(*line.T)
#     626
#
# <ipython-input-1610-afc227cedd22> in fitline(self, cluster, steps, eps)
#     325
#     326         for i in range(steps):
# --> 327             g = sc.optimize.approx_fprime(x, self.cost, [eps]*3 + [eps]*3, hit_pts, miss_pts)
#     328             x -= g*eps
#     329
#
# ~/opt/anaconda3/envs/UROP/lib/python3.7/site-packages/scipy/optimize/optimize.py in approx_fprime(xk, f, epsilon, *args)
#     763
#     764     """
# --> 765     return _approx_fprime_helper(xk, f, epsilon, args=args)
#     766
#     767
#
# ...

# %%
mc.show_cluster(5)

# %%
epsilon = 10e-6
linepoints = mc.tracks[4]

rayDirection = linepoints[1] - linepoints[0]
rayPoint = linepoints[0]
cubeLength = 50

#start = time.time()

hit_channels = []
miss_channels = []

for channel in range(1,len(mc.coords)+1):
    cubeCenter = mc.coords[channel]

    #check if cubeCenter is within range of line
    CP = cubeCenter - linepoints[0]
    distance_to_line = np.abs(np.linalg.norm(cross(CP,rayDirection)) / np.linalg.norm(rayDirection))

    #print(distance_to_line)

    if distance_to_line < cubeLength/2*np.sqrt(3) + epsilon:

        collision = mc.linecubecollision(cubeCenter, cubeLength, rayDirection, rayPoint)
        if len(collision) == 2:
            hit_channels.append(channel)
        else:
            miss_channels.append(channel)

print(hit_channels)
print(miss_channels)
# Out:
# [348, 349, 431, 445, 446, 460, 461]
# [347, 350, 430, 432, 444, 447, 459, 462]

# %%
hit_channel_coords = np.array([mc.coords[channel] for channel in hit_channels])
miss_channel_coords = np.array([mc.coords[channel] for channel in miss_channels])


plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.set_proj_type('ortho')

ax.scatter3D(*hit_channel_coords.T)
ax.scatter3D(*miss_channel_coords.T)
ax.plot3D(*linepoints.T)

plt.xlim([-350,350])
plt.ylim([-350,350])
ax.set_zlim([-350,350])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.view_init(15, 45)

plt.show()

print("NRMSE: " + str(DataAnalysis().clusterNRMSE(mc.get_data())))
# Out:
# NRMSE: 7.727789393445186

# %%
A = hit_channel_coords.T
B = miss_channel_coords.T

# %%
from scipy import optimize

data = np.array(A).T

datamean = data.mean(axis=0)
# Do an SVD on the mean-centered data.
uu, dd, vv = np.linalg.svd(data - datamean)

#cost(np.append(vv[0], datamean))

#x = np.ones(6)
x = np.append(vv[0], datamean)

for i in range(500):
    #x = np.array([.9, .1])
    #eps = np.sqrt(np.finfo(float).eps)
    eps = np.float(1e-2)
    g = optimize.approx_fprime(x, cost, eps)
    x -= g*eps

p = x[:3]
v = x[3:]
linepts = v * np.mgrid[-5:5:2j][:, np.newaxis] + p
linepts
# Out:
# array([[ -409.34972927,   624.64486934,  1566.48301669],
#        [  485.22311955,     9.98834095, -1204.72543384]])

# %%
hitchannels = mc.channelcollisions(linepts)
clusterchannels = da2.get_cluster(3)['Channel'].unique()

missing = [ch for ch in hitchannels if ch not in clusterchannels]
extra = [ch for ch in clusterchannels if ch not in hitchannels]

print(missing)
print(extra)
# Out:
# /Users/julianyocum/opt/anaconda3/envs/UROP/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1041-74f913ca711a> in <module>
#       3
#       4 missing = [ch for ch in hitchannels if ch not in clusterchannels]
# ----> 5 extra = [ch for ch in clusterchannels if ch not in hitchannels]
#       6
#       7 print(missing)
#
# <ipython-input-1041-74f913ca711a> in <listcomp>(.0)
#       3
#       4 missing = [ch for ch in hitchannels if ch not in clusterchannels]
# ----> 5 extra = [ch for ch in clusterchannels if ch not in hitchannels]
#       6
#       7 print(missing)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
from pymoo.util.misc import stack
from pymoo.model.problem import Problem

class MyProblem(Problem):

    def __init__(self):
        super().__init__(n_var=2,
                         n_obj=2,
                         n_constr=2,
                         xl=np.array([-2,-2]),
                         xu=np.array([2,2]))

    def _evaluate(self, x, out, *args, **kwargs):
        f1 = x[:,0]**2 + x[:,1]**2
        f2 = (x[:,0]-1)**2 + x[:,1]**2

        g1 = 2*(x[:, 0]-0.1) * (x[:, 0]-0.9) / 0.18
        g2 = - 20*(x[:, 0]-0.4) * (x[:, 0]-0.6) / 4.8

        out["F"] = np.column_stack([f1, f2])
        out["G"] = np.column_stack([g1, g2])

# %%
from pymoo.algorithms.nsga2 import NSGA2
from pymoo.factory import get_sampling, get_crossover, get_mutation

algorithm = NSGA2(
    pop_size=40,
    n_offsprings=10,
    sampling=get_sampling("real_random"),
    crossover=get_crossover("real_sbx", prob=0.9, eta=15),
    mutation=get_mutation("real_pm", eta=20),
    eliminate_duplicates=True
)

# %%
from pymoo.factory import get_termination

termination = get_termination("n_gen", 40)

# %%
from pymoo.optimize import minimize

problem = MyProblem()

res = minimize(problem,
               algorithm,
               termination,
               seed=1,
               pf=problem.pareto_front(use_cache=False),
               save_history=True,
               verbose=True)
# Out:
# ...
# n_gen |  n_eval |   cv (min)   |   cv (avg)   |  n_nds  | delta_ideal  | delta_nadir  |   delta_f
# ...
#     1 |      40 |  0.00000E+00 |  2.36399E+01 |       1 |            - |            - |            -
#     2 |      50 |  0.00000E+00 |  1.15486E+01 |       1 |  0.00000E+00 |  0.00000E+00 |  0.00000E+00
#     3 |      60 |  0.00000E+00 |  5.277918607 |       1 |  0.00000E+00 |  0.00000E+00 |  0.00000E+00
#     4 |      70 |  0.00000E+00 |  2.406068542 |       2 |  1.000000000 |  1.000000000 |  0.707106781
#     5 |      80 |  0.00000E+00 |  0.908316880 |       3 |  0.869706146 |  0.950815918 |  0.429526831
#     6 |      90 |  0.00000E+00 |  0.264746300 |       3 |  0.00000E+00 |  0.00000E+00 |  0.00000E+00
#     7 |     100 |  0.00000E+00 |  0.054063822 |       4 |  0.023775686 |  0.540441957 |  0.135241172
#     8 |     110 |  0.00000E+00 |  0.003060876 |       5 |  0.127815454 |  0.209332793 |  0.049053851
# ...

# %%
res.X
# Out:
# array([[ 0.11510051,  0.01138721],
#        [ 0.86581527, -0.00928733],
#        [ 0.60242256,  0.08472022],
#        [ 0.39616904,  0.05312622],
#        [ 0.15518481, -0.05883016],
#        [ 0.19343429, -0.03395209],
#        [ 0.22508327, -0.06072936],
#        [ 0.25077311, -0.02853695],
#        [ 0.34736889,  0.00610324],
#        [ 0.72009242,  0.00262769],
#        [ 0.32304369,  0.05982215],
#        [ 0.84219645,  0.03333475],
#        [ 0.2651668 ,  0.0520986 ],
#        [ 0.78504045,  0.01428644],
#        [ 0.70245204,  0.01079545],
#        [ 0.2942131 , -0.02694028],
#        [ 0.28278564, -0.06018309],
#        [ 0.31317387, -0.02646671],
#        [ 0.66363419,  0.01461327],
#        [ 0.62013562,  0.05955645],
#        [ 0.80773981,  0.00975323],
#        [ 0.65517858,  0.05955645],
#        [ 0.68343574, -0.03342387],
#        [ 0.63656334,  0.00975323],
#        [ 0.36152464, -0.06072936],
#        [ 0.3829705 ,  0.0149761 ],
#        [ 0.74839333, -0.03369918],
# ...

# %%
res.F
# Out:
# array([[0.0133778 , 0.78317678],
#        [0.74972234, 0.0180918 ],
#        [0.37009045, 0.16524534],
#        [0.1597723 , 0.36743422],
#        [0.02754331, 0.71717369],
#        [0.03856957, 0.65170098],
#        [0.05435053, 0.60418399],
#        [0.06370151, 0.5621553 ],
#        [0.1207024 , 0.42596461],
#        [0.51854   , 0.07835516],
#        [0.10793592, 0.46184853],
#        [0.71040607, 0.02601317],
#        [0.0730277 , 0.54269409],
#        [0.61649262, 0.04641171],
#        [0.49355541, 0.08865133],
#        [0.08728713, 0.49886093],
#        [0.08358972, 0.51801844],
#        [0.09877836, 0.47243062],
#        [0.44062389, 0.1133555 ],
#        [0.38811515, 0.14784392],
#        [0.65253873, 0.0370591 ],
#        [0.43280594, 0.12244878],
#        [0.46820156, 0.10133009],
#        [0.40530801, 0.13218133],
#        [0.13438812, 0.41133884],
#        [0.14689069, 0.38094968],
#        [0.56122821, 0.06444155],
#        [0.01865085, 0.75394714],
# ...

# %%
da2.get_cluster(4)['Channel'].values
# Out:
# array([347, 346, 361, 360, 345])

# %%
def make_graph(hitpts, misspts, linepts):
    #hit_channel_coords = np.array([self.coords[channel] for channel in hit_channels])
    plt.figure(figsize=(10,10))
    ax = plt.axes(projection='3d')
    ax.set_proj_type('ortho')

    if not hitpts.size == 0:
        ax.scatter3D(*hitpts)
        
    if not misspts.size == 0:
        ax.scatter3D(*misspts)
    
    ax.plot3D(*linepts.T)

    plt.xlim([-350,350])
    plt.ylim([-350,350])
    ax.set_zlim([-350,350])

    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')

    ax.view_init(15, 75)

    plt.show()


# takes dataframe of a single cluster and finds line of best fit
def basicfit(cluster):
    coords = testDataAnalysis().clustercoords(cluster)

    data  = np.array(coords).T

    datamean = data.mean(axis=0)

    # Do an SVD on the mean-centered data.
    uu, dd, vv = np.linalg.svd(data - datamean)

    linepts = vv[0] * np.mgrid[-400:400:2j][:, np.newaxis]

    # shift by the mean to get the line in the right place
    linepts += datamean

    #return linepts
    return (datamean, vv[0])


def ptsfromline( pts, linepts):

    dlist = []

    a = linepts[0]
    b = linepts[1]

    for i in range(len(pts[0])):

        p = np.array([pts[0][i], pts[1][i], pts[2][i]])            
        d = np.linalg.norm(cross(p-a, p-b)) / np.linalg.norm(b-a)

        dlist.append(d)

    return dlist


# x = [p0,p1,p2,v0,v1,v2]
def cost ( x, hit_pts, miss_pts): 
    p = x[:3]
    v = x[3:]

    linepts = v * np.mgrid[-.5:.5:2j][:, np.newaxis] + p

    hitlist = ptsfromline(hit_pts, linepts)
    misslist = ptsfromline(miss_pts, linepts)
    
    cubeLength = 50
    inside = cubeLength/2*np.sqrt(3)
    
    
    if len(misslist) == 0:
        return sum([1/(1 + math.e**(-.1*(d-30))) for d in hitlist])

    #print(Alist)
    #print(Blist)
    #(len(misslist))**2
    #return sum([d**2 for d in hitlist]) + len(hitlist) / (len(hitlist) + len(misslist)) * sum([d**2 for d in misslist])
    
    
    #return sum([d**2 for d in hitlist]) + sum([(inside)**4/d**2 for d in misslist]) #Best so far
    
    value1 = sum([1/(1 + math.e**(-.1*(d-30))) for d in hitlist])
    value2 = sum([1/(1 + math.e**(.1*(d-inside))) for d in misslist])
    
    #print(value1)
    #print(value2)
    #print()
    
    return value1 + value2

# takes dataframe of a single cluster and finds line of best fit
def fitline(cluster, trials = 10, steps=100, eps=1e-2):

    p0, v0 = basicfit(cluster)

    linepts = v0 * np.mgrid[-400:400:2j][:, np.newaxis] + p0

    #cost(np.append(vv[0], datamean))
    #x = np.ones(6)
    x = np.append(p0, v0)
    
    first_hit_chs, first_miss_chs = testDataAnalysis().channelcollisions(linepts)

    want_to_hit_chs = cluster['Channel'].values
    want_to_miss_chs = [ch for ch in first_hit_chs if ch not in want_to_hit_chs]

    for i in range(trials):
        
        linepts = x[3:] * np.mgrid[-400:400:2j][:, np.newaxis] + x[:3]
        
        hit_chs, miss_chs = testDataAnalysis().channelcollisions(linepts)
            
        for ch in hit_chs:
            if ch not in want_to_hit_chs and ch not in want_to_miss_chs:
                want_to_miss_chs.append(ch)
        #print(want_to_miss_chs)
                
                
        
        hit_pts = np.array([da.coords[channel] for channel in want_to_hit_chs]).T
        miss_pts = np.array([da.coords[channel] for channel in want_to_miss_chs]).T
        

        if len(want_to_miss_chs) == 0:
            print("Here")
            #make_graph(hit_pts, miss_pts, linepts)
            return linepts
        
        for j in range(steps):
            
            g = sc.optimize.approx_fprime(x, cost, [ eps]*3 + [eps]*3, hit_pts, miss_pts)
            
            #print(g)
            x -= g*eps

    p = x[:3]
    v = x[3:] / np.linalg.norm(x[3:])

    
    betterlinepts = v * np.mgrid[-400:400:2j][:, np.newaxis] + p
    
    make_graph(hit_pts, miss_pts, betterlinepts)
    
    print(sorted(want_to_hit_chs))
    print(want_to_miss_chs)
    
    actually_hit = testDataAnalysis().channelcollisions(betterlinepts)[0]
    print()
    print(actually_hit)
    
    print("Missing: " + str(len([ch for ch in want_to_hit_chs if ch not in actually_hit])))
    print("Extra: " + str(len([ch for ch in actually_hit if ch not in want_to_hit_chs])))

    return betterlinepts




betterlinepts = fitline(mc.get_cluster(0))
print()
print()
# Out:
#   File "<ipython-input-2103-4de2e01da4a7>", line 79
#     if len(misslist) = 0:
#                      ^
# SyntaxError: invalid syntax

# %%
ch_list = [712]
pts = np.array([da.coords[channel] for channel in ch_list]).T
ptsfromline( pts, betterlinepts)
# Out:
# [32.38524629342235]

# %%
1/(1 + math.e**(.1*(50-60)))
# Out:
# 0.7310585786300049

# %%
da1.get_clusterdf()#mc.get_tracks()[5]
# Out:
#    Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0      12        12  7.924100e+05         0.0  0.799906  0.781604
# 1        1      10        10  1.988182e+06         0.0  1.022473  1.058378
# 2        2      14        14  1.997571e+06         0.0  0.868092  0.924203
# 3        3       6         6  2.023319e+06         0.0  0.651467  1.366407
# 4        4       8         8  2.602365e+06         0.0  0.848489  1.463333
#
#     Azimuth  ExtraCh  MissingCh
# 0  0.012926        0          1
# 1 -1.370503        2          1
# 2 -0.452301        1          0
# 3  0.000000        0          0
# 4  0.675213        3          0

# %%
mc.get_clusterdf()
# Out:
#    Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0      12        12  7.924100e+05         0.0  0.881025  0.772491
# 1        1      10        10  1.988182e+06         0.0  1.074111  1.055971
# 2        2      14        14  1.997571e+06         0.0  0.899298  0.906606
# 3        3       6         6  2.023319e+06         0.0  1.011864  1.338762
# 4        4       8         8  2.602365e+06         0.0  0.980412  1.498909
#
#     Azimuth  ExtraCh  MissingCh
# 0  0.075146        0          0
# 1 -1.390983        0          0
# 2 -0.469227        0          0
# 3 -0.000803        0          0
# 4  0.637748        0          0

# %%
mc.show_cluster(4, 15, 75)

# %%
da1.show_cluster(1, 15, 75)

# %%
# %run MonteCarlo.ipynb
da2.channelcollisions(mc.get_tracks()[0])
# Out:
# ([30, 31, 185, 240, 252, 631, 644, 670, 736, 749, 776],
#  [43, 56, 239, 253, 643, 775])

# %%
cluster = da2.get_cluster(4)

p0, v0 = basicfit(cluster)

lineppts = v0 * np.mgrid[-400:400:2j][:, np.newaxis] + p0

first_hit_chs, first_miss_chs = DataAnalysis().channelcollisions(linepts)

want_to_hit_chs = cluster['Channel'].values
#want_to_miss_chs = [ch for ch in (first_hit_chs + first_miss_chs) if ch not in want_to_hit_chs]
#want_to_hit_chs = [ch for ch in cluster['Channel'].unique() if ch not in first_hit_chs]
want_to_miss_chs = [ch for ch in first_hit_chs if ch not in want_to_hit_chs]

hit_pts = np.array([da.coords[channel] for channel in want_to_hit_chs]).T
miss_pts = np.array([da.coords[channel] for channel in want_to_miss_chs]).T

#cost(np.append(vv[0], datamean))
#x = np.ones(6)
x = np.append(p0, v0)

# %%
from pymoo.util.misc import stack
from pymoo.model.problem import Problem

class MyProblem(Problem):

    def __init__(self):
        super().__init__(n_var=2,
                         n_obj=2,
                         n_constr=2,
                         xl=np.array([-2,-2]),
                         xu=np.array([2,2]))

    def _evaluate(self, x, out, *args, **kwargs):
        f1 = x[:,0]**2 + x[:,1]**2
        f2 = (x[:,0]-1)**2 + x[:,1]**2

        g1 = 2*(x[:, 0]-0.1) * (x[:, 0]-0.9) / 0.18
        g2 = - 20*(x[:, 0]-0.4) * (x[:, 0]-0.6) / 4.8

        out["F"] = np.column_stack([f1, f2])
        out["G"] = np.column_stack([g1, g2])

# %%
x = np.array([[1,2,3,4,5,6], [4,5,6,7,8,9], [7,8,9,10,11,12]])

p = x[:,:3]
v = x[:,3:]

print(p)
print(v)

v * np.mgrid[-.5:.5:2j][:, np.newaxis]
v * np.mgrid[-.5:.5:2j][:, np.newaxis] + p
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
# [[ 4  5  6]
#  [ 7  8  9]
#  [10 11 12]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1571-3a36fa37cdb4> in <module>
#       7 print(v)
#       8
# ----> 9 v * np.mgrid[-.5:.5:2j][:, np.newaxis]
#      10 v * np.mgrid[-.5:.5:2j][:, np.newaxis] + p
#      11
#
# ValueError: operands could not be broadcast together with shapes (3,3) (2,1)

# %%
a, b = 
hitlist = ptsfromline(hit_pts, linepts)
misslist = ptsfromline(miss_pts, linepts)

#return sum([d**2 for d in hitlist]) - 1/25 * (sum([d**2 for d in misslist]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1568-185e4f21265f> in <module>
#       2 v = x[:,3:]
#       3
# ----> 4 a, b = v * np.mgrid[-.5:.5:2j][:, np.newaxis] + p
#       5
#       6 hitlist = ptsfromline(hit_pts, linepts)
#
# ValueError: operands could not be broadcast together with shapes (3,3) (2,1)

# %%
def ptsfromline( pts, linepts):

    dlist = []

    a = linepts[0]
    b = linepts[1]

    for i in range(len(pts[0])):

        p = np.array([pts[0][i], pts[1][i], pts[2][i]])            
        d = np.linalg.norm(cross(p-a, p-b)) / np.linalg.norm(b-a)

        dlist.append(d)

    return dlist

# %%
# built algorithm which generates a line which:
#    gaurantees that all given channels are intersected / near
#           '''          given channels are not intersected / near
#
