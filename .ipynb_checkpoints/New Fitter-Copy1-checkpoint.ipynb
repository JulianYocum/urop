# %%
import time

# %run MonteCarlo.ipynb
# Out:
# 1.1825911884369926
# -1.5985822508819123
#
# 1.1825911884369926
# -0.9660749299591673
#
# 0.5262283438036521 -0.7614463182000234 0.37852771982682315

# %%
mc = MonteCarlo(5,"sasso")
mc.get_clusterdf()
# Out:
#    Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0       7         7   6194.824630         0.0  0.860111  0.887333
# 1        1      10        10  17096.240902         0.0  1.073893  0.685902
# 2        2      15        15  18494.347310         0.0  0.966569  1.106474
# 3        3       9         9  31645.127702         0.0  1.103334  0.705283
# 4        4      10        10  47053.049565         0.0  0.924129  0.543510
#
#     Azimuth  ExtraCh  MissingCh        dEdx  dEdx_err  \
# 0 -0.094482        0          0  958.566725  0.000000
# 1  1.406252        0          0  104.246477  0.000000
# 2 -1.141558        0          0  364.305170  0.000000
# 3  1.239740        0          0  706.594465  0.000004
# 4  1.281009        0          0  743.788480  0.000000
#
#                                              Fitline
# 0  [-42.676966, -231.162448, 233.88372, -0.665845...
# 1  [28.296153, -277.714706, 23.223322, 0.285694, ...
# 2  [116.611763, -65.50911, -242.969913, -0.780757...
# 3  [224.963086, 343.698087, -151.318578, 0.192469...
# 4  [-33.275612, 306.329539, -120.714539, 0.173786...

# %%
# %run new_DataAnalysis.ipynb
data = testDataAnalysis()
data.set_eventdf(mc.get_eventdf())

start = time.time()

data.make_clusterdf(pop_num=50, gen_num=200)
print('run time: ' + str(time.time() - start))

data.get_clusterdf()
# Out:
# run time: 4170.052093029022
#    Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0       7         7   6194.824630         0.0  0.931860  0.878759
# 1        1      10        10  17096.240902         0.0  0.974101  0.639884
# 2        2      15        15  18494.347310         0.0  0.966539  1.107015
# 3        3       9         9  31645.127702         0.0  0.993126  0.641829
# 4        4      10        10  47053.049565         0.0  0.998667  0.505407
#
#     Azimuth  ExtraCh  MissingCh        dEdx  dEdx_err  \
# 0 -0.127910        0          0  909.126888 -0.067141
# 1  1.413252        0          0   74.991778 -0.000893
# 2 -1.140996        0          0  363.904286  0.999210
# 3  1.244188        0          0  654.985668  0.527114
# 4  1.441114        0          0  780.782258 -0.001398
#
#                                              Fitline
# 0  [-111.8921, -268.078053, 302.964612, 0.673989,...
# 1  [-35.447247, -169.351703, -122.759194, -0.2730...
# 2  [-306.524238, 170.72241, -0.381053, 0.781213, ...
# 3  [344.929511, -38.361586, 345.899216, -0.180287...
# 4  [-51.43363, 306.192442, -148.256362, 0.23332, ...

# %%
data.get_clusterdf()
# Out:
#    Cluster  Events  Channels    StartTime  TimeSpread     NRMSE   Zenith  \
# 0        0      10        10  2113.598439         0.0  1.120862  0.50286
#
#     Azimuth  ExtraCh  MissingCh        dEdx  dEdx_err  \
# 0 -0.623369        0          0  266.278408  3.101689
#
#                                              Fitline
# 0  [-197.155584, 206.42174, -270.42434, 0.481913,...

# %%
data.show_cluster(0)

# %%
mc.show_cluster(0)

# %%
#cluster = da1.get_eventdf()[~np.isnan(da1.get_eventdf()['PathLength'].values)]
c = 0

df = data.get_cluster(c)[data.get_cluster(c)['Hit'] == True]

plt.scatter(df['PathLength'], df['SelectedEnergy'])

x = df['PathLength'][:,np.newaxis]            
y = df['SelectedEnergy']

slope, _, _, _ = np.linalg.lstsq(x, y.values)
m = slope[0]

print(m)
f = np.poly1d([m,0])

r2 = r2_score(y, df['PathLength'].values * m)

print(y.values)
print(f(df['PathLength']))

#slope, intercept, r_value, p_value, std_err = stats.linregress(df['PathLength'], df['SelectedEnergy'])
print(m)
print(r2)
print()

plt.plot(np.linspace(0,60,10), f(np.linspace(0,60,10)))

print()
plt.figure()

df = mc.get_cluster(c)[mc.get_cluster(c)['Hit'] == True]

plt.scatter(df['PathLength'], df['SelectedEnergy'])

slope, intercept, r_value, p_value, std_err = stats.linregress(df['PathLength'], df['SelectedEnergy'])
print(r_value**2)
print(slope)
print(intercept)
print(std_err)

plt.plot(np.linspace(0,60,10), np.linspace(0,60,10) * slope + intercept)
# Out:
# 887.451792583838
# [51492.01167148 53890.82069604 17182.11881331 34733.14948377
#  25104.35487431 57050.0505613  34076.01301529]
# [19109.26864622 62635.85219135  1188.3736566  29006.31582722
#  25955.32416109 55266.10024511 41997.52144766]
# 887.451792583838
# -0.04611591695789752
#
#
# 1.0
# 958.5667248484865
# 1.4551915228366852e-11
# 0.0

# %%
b = np.arange(6)

# %%
b[np.newaxis].T[:3]
# Out:
# array([[0],
#        [1],
#        [2]])

# %%
b[np.newaxis].T[3:]
# Out:
# array([[3],
#        [4],
#        [5]])

# %%
inside = 50/2*np.sqrt(3)
hitlist = [16.43587724, 31.09163355, 36.81796376 ,27.57519066, 21.19238015 ,32.55493693,
 16.91716155,29.58457112, 36.27159523, 22.21526205, 35.07915558, 21.27645207,
 30.55399903 ,29.05623664]

# %%
linecost =  ([1/(1 + np.exp(-.2*(d-inside))) for d in hitlist])

# %%
linecost
# Out:
# [0.004618396628571809,
#  0.08003089591961807,
#  0.21472745330511517,
#  0.0412801992429101,
#  0.011870258647963452,
#  0.10439977161851902,
#  0.005082676100409584,
#  0.060463896377684165,
#  0.19687600666777036,
#  0.014525727569109309,
#  0.16186413297284957,
#  0.012069107927827926,
#  0.0724631591088451,
#  0.05473268436336236]

# %%
np.sum(linecost)
# Out:
# 1.0350043664505562
