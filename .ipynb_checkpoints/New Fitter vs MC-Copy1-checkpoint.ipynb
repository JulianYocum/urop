# %%
import time
import matplotlib.pyplot as plt
import numpy as np

from oldDataAnalysis import DataAnalysis
#%run new_DataAnalysis.ipynb|
from MonteCarlo import MonteCarlo

# %%
# data = DataAnalysis()
# data.load_eventdf('data/new_moo/8-5/events.csv')
# data.load_clusterdf('data/new_moo/8-5/clusters.csv')
# data.filter_fit(3.5, 5) #(NRMSE, channels)
# data.get_cluster(0)

# %%
mc = MonteCarlo(num_tracks=20, track_type="sasso", particle_type="muon")
mc.filter_fit(100, 3)
#mc.get_eventdf()

# %%
# from pymoo.visualization.scatter import Scatter
# test = DataAnalysis()
# line, pre_result, fin_result = test.fitline(mc.get_cluster(0), pop_num=50, gen_num=50)

# %%
# plot = Scatter(title = "Objective Space", angle=(0,45))
# plot.add(pre_result.F)
# plot.show()

# %%
# plot = Scatter(title = "Objective Space", angle=(0,45))
# plot.add(fin_result.F[:,:2])
# plot.show()

# %%
start = time.time()

test = DataAnalysis()

#test.set_eventdf(mc.get_eventdf())
#test.set_eventdf(mc.get_cluster(1))
test.load_eventdf('data/new_moo/3-29/events.csv')

#test.arrange_clusters(3, 1.0) # >= 5 events, <= 1.0 seconds
test.make_clusterdf(pop_num=100, gen_num=100, verbose=False)

#test.save_eventdf("./data/test_eventdf.csv")
#test.save_clusterdf("./data/test_clusterdf.csv")

time.time() - start
# Out:
# using old...
# using old...
# using old...
# using old...
# using old...
# using old...
# using old...
# using old...
# using old...
# using old...
# using old...
# Many-Objective Failure, defaulting to Multi-Objective...
# using old...
# using old...
# using old...
# using old...
# 2659.709739923477

# %%
test.get_clusterdf()
# Out:
#     Cluster  Events  Channels      StartTime  TimeSpread     NRMSE    Zenith  \
# 0         0       3         3   36814.899851         0.0  1.181436  0.819069
# 1         1       1         1   57906.335822         0.0  0.000000  1.570796
# 2         2      14        14   70755.951435         0.0  0.926323  0.499865
# 3         3       8         8   88140.624595         0.0  0.957708  0.508152
# 4         4       4         4  110273.199505         0.0  1.007118  0.426622
# 5         5       4         4  131062.925679         0.0  1.070241  0.173729
# 6         6      11        11  136796.432224         0.0  0.851744  0.503643
# 7         7      12        12  144094.236759         0.0  0.826185  0.544493
# 8         8       7         7  159886.449023         0.0  0.976186  0.508927
# 9         9      11        11  161443.604545         0.0  0.845275  0.693204
# 10       10      12        12  177094.597554         0.0  0.953849  0.985789
# 11       11      13        13  180946.273946         0.0  0.897212  0.461652
# 12       12       4         4  185572.662776         0.0  0.956290  0.352327
# 13       13      11        11  188765.873165         0.0  0.957555  0.467743
# 14       14       5         5  199401.001197         0.0  1.140288  0.930220
#
#      Azimuth  ExtraCh  MissingCh  \
# 0   0.791870        0          0
# 1  -0.632507        1          0
# 2  -1.160524        0          0
# 3   1.193877        0          0
# 4  -0.082379        0          0
# 5  -0.008667        0          0
# 6  -0.744965        0          0
# 7  -0.545600        0          0
# 8  -0.049082        0          0
# 9   1.020057        0          0
# 10 -0.230543        0          0
# 11 -0.113648        0          0
# 12 -0.290963        0          0
# 13  0.378204        0          0
# 14  1.180782        0          0
#
#                                               Fitline
# 0   [329.388816, 37.664078, 358.141504, 0.106579, ...
# 1                 [-29.7, 323.4, 58.0, 1.0, 0.0, 0.0]
# 2   [178.614128, -102.277387, 10.869075, 0.414029,...
# 3   [-264.8055, -22.381103, 110.486714, -0.12301, ...
# 4   [-259.804113, -197.821304, 34.661716, 0.352745...
# 5   [-320.166241, 202.307877, 124.844117, -0.14029...
# 6   [-40.245837, -177.931368, -254.683162, 0.47957...
# 7   [43.769816, -170.646523, 304.432319, -0.51603,...
# 8   [-164.830586, 123.81849, 4.684791, -0.406642, ...
# 9   [-249.443699, -101.343105, -297.360763, -0.052...
# 10  [-21.094873, 120.773259, 173.612218, -0.767257...
# 11  [122.528658, -45.65658, -280.849212, -0.386803...
# 12  [318.875904, 112.34381, 251.549197, 0.32515, 0...
# 13  [103.986275, -96.965064, -55.128442, -0.23953,...
# 14  [-308.752663, -164.293294, -227.775003, -0.192...

# %%
mc.get_clusterdf(fitline=False)
# Out:
#     Cluster  Events  Channels      StartTime  TimeSpread     NRMSE    Zenith  \
# 0         0       6         6   14694.632347         0.0  1.156173  1.083654
# 1         1      10        10   23529.052833         0.0  0.874501  0.322283
# 2         2       7         7   26037.163934         0.0  1.058268  0.976995
# 3         3       6         6   54144.591587         0.0  0.818962  0.451974
# 4         4      13        13   56248.662301         0.0  0.772319  0.295955
# 5         5       4         4   59609.839145         0.0  1.333077  0.652123
# 7         7       8         8   69703.650516         0.0  0.870371  0.843841
# 8         8      12        12   79511.460100         0.0  0.992716  0.656383
# 9         9      12        12   90033.974131         0.0  0.970398  0.623420
# 10       10       5         5  108638.127316         0.0  1.232238  0.661829
# 11       11      14        14  124998.416262         0.0  1.016008  0.990710
# 12       12       5         5  126681.141693         0.0  1.060140  0.407533
# 13       13       7         7  169788.796341         0.0  1.006418  0.172693
# 14       14      14        14  170634.904368         0.0  0.895790  0.641450
# 15       15      11        11  207058.646842         0.0  0.752436  0.410533
# 16       16       8         8  211898.106068         0.0  0.985883  1.241062
# 17       17      11        11  219906.564581         0.0  0.990227  0.492876
#
#      Azimuth  ExtraCh  MissingCh  Likelihood
# 0  -0.578070        0          0  -12.332606
# 1  -1.160740        0          0  -30.131089
# 2  -0.827964        0          0  -19.930100
# 3  -0.695082        0          0  -14.553814
# 4   0.836110        0          0  -33.772830
# 5  -1.524247        0          0   -8.890872
# 7   0.580111        0          0  -19.887216
# 8  -0.463067        0          0  -45.101072
# 9   1.551046        0          0  -31.768553
# 10  0.210403        0          0  -16.127602
# 11 -1.562815        0          0  -48.691242
# 12 -1.222221        0          0  -17.100789
# 13 -0.925139        0          0  -29.763531
# 14 -0.267864        0          0  -35.952571
# 15  0.981058        0          0  -33.502340
# 16  0.096348        0          0  -18.520684
# 17  1.377035        0          0  -26.517873

# %%
test.get_cluster(0)
# Out:
#    Run  Channel          Time  NumPulses  OFdelay  MaxPosInWindow  \
# 0    0      507  36811.699851          1      3.2             3.2
# 1    0      545  36811.699851          1      3.2             3.2
# 2    0      557  36811.699851          1      3.2             3.2
#
#    SelectedEnergy  Baseline  MaxToBaseline  StabAmp  IsSaturated  Track  \
# 0    37969.964238       0.0            0.0      0.0        False      0
# 1    42057.824593       0.0            0.0      0.0        False      0
# 2    18691.472356       0.0            0.0      0.0        False      0
#
#         MaxTime  Cluster   Hit  PathLength        dEdx
# 0  36814.899851        0  True   44.915581  845.362862
# 1  36814.899851        0  True   60.375291  696.606576
# 2  36814.899851        0  True   23.813573  784.908347

# %%
mc.get_cluster(0)
# Out:
#    Run  Channel          Time  NumPulses  OFdelay  MaxPosInWindow  \
# 0    0       89  14691.432347          1      3.2             3.2
# 1    0      102  14691.432347          1      3.2             3.2
# 2    0      103  14691.432347          1      3.2             3.2
# 3    0      450  14691.432347          1      3.2             3.2
# 4    0      451  14691.432347          1      3.2             3.2
# 5    0      464  14691.432347          1      3.2             3.2
#
#    SelectedEnergy  Baseline  MaxToBaseline  StabAmp  IsSaturated  Track  \
# 0    56512.611281       0.0            0.0      0.0        False      0
# 1     1739.978549       0.0            0.0      0.0        False      0
# 2    15994.918703       0.0            0.0      0.0        False      0
# 3    24004.530328       0.0            0.0      0.0        False      0
# 4     7043.797448       0.0            0.0      0.0        False      0
# 5    44339.872361       0.0            0.0      0.0        False      0
#
#         MaxTime  Cluster   Hit  PathLength        dEdx
# 0  14694.632347        0  True   56.665871  997.295375
# 1  14694.632347        0  True    2.134876  815.025465
# 2  14694.632347        0  True   21.808712  733.418760
# 3  14694.632347        0  True   30.935535  775.953303
# 4  14694.632347        0  True    8.640051  815.249561
# 5  14694.632347        0  True   56.665871  782.479320

# %%
# clean_test = copy(test)
# clean_test.clusterdf = test.get_clusterdf()[test.get_clusterdf['ExtraCh']]
# clean_test.eventdf = clean_test.eventdf[clean_test.eventdf['Cluster'].isin(clean_test.clusterdf['Cluster'].values)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ea7924000d97> in <module>
# ----> 1 clean_test = copy(test)
#       2 clean_test.clusterdf = test.get_clusterdf()[test.get_clusterdf['ExtraCh']]
#       3 clean_test.eventdf = clean_test.eventdf[clean_test.eventdf['Cluster'].isin(clean_test.clusterdf['Cluster'].values)]
#
# NameError: name 'copy' is not defined

# %%
clean_test.clusterdf

# %%
from Helper import *
import copy

clean_test = copy.deepcopy(test)
# clean_test.clusterdf = clean_test.clusterdf[clean_test.clusterdf['ExtraCh'] == 0]
# clean_test.eventdf = clean_test.eventdf[clean_test.eventdf['Cluster'].isin(clean_test.clusterdf['Cluster'].values)]

clean_mc = copy.deepcopy(mc)
# clean_mc.clusterdf = clean_mc.clusterdf[clean_mc.clusterdf['Cluster'].isin(clean_test.clusterdf['Cluster'].values)]
# clean_mc.eventdf = clean_mc.eventdf[clean_mc.eventdf['Cluster'].isin(clean_test.clusterdf['Cluster'].values)]


dEdx_pdf = make_pdf('./data/pdf/dEdx/bins_dEdx_muon.csv', './data/pdf/dEdx/values_dEdx_muon.csv', domain_range=[0,190])
clusters = np.array(mc.get_clusterdf()['Cluster'])

log_likelihoods_mc = [np.log(dEdx_pdf(np.array(clean_mc.get_cluster(c)['dEdx'])/100)).sum() for c in clusters]
log_likelihoods_test = [np.log(dEdx_pdf(np.array(clean_test.get_cluster(c)['dEdx'])/100)).sum() for c in clusters]


# min_path_test = test.get_eventdf()[test.get_eventdf()['PathLength'] > 30]
# min_path_mc = mc.get_eventdf()[test.get_eventdf()['PathLength'] > 30]

plt.figure(figsize=(12,8))

plt.subplot(2,3,1)
plt.title("dEdx")
#plt.scatter(np.array(mc.get_eventdf()['dEdx'])/100, np.array(test.get_eventdf()['dEdx'])/100, s=5)
plt.scatter(clean_test.get_eventdf()['dEdx']/100, clean_mc.get_eventdf()['dEdx']/100, s=5)
plt.xlabel("MeV/cm (reconstructed)")
plt.ylabel("MeV/cm (generated)")
plt.xlim(4,30)
plt.ylim(4,30)
plt.xscale('log')
plt.yscale('log')

plt.subplot(2,3,2)
plt.title("dEdx log-likelihoods")
plt.scatter(log_likelihoods_mc, log_likelihoods_test, s=5)
plt.xlim(-100,0)
plt.ylim(-100,0)
plt.xlabel("log(likelihood) (generated)")
plt.ylabel("log(likelihood) (reconstructed)")

plt.subplot(2,3,3)
plt.title("Pathlengths")
plt.scatter( np.array(clean_mc.get_eventdf()['PathLength']), np.array(clean_test.get_eventdf()['PathLength']), s=5)
plt.ylabel("mm (reconstructed)")
plt.xlabel("mm (generated)")
plt.xlim(0,80)
plt.ylim(0,80)

plt.subplot(2,3,4)
plt.title("Zenith")
plt.scatter(np.array(clean_mc.get_clusterdf()['Zenith']) * 180 / np.pi, np.array(clean_test.get_clusterdf()['Zenith']) * 180 / np.pi, s=5)
plt.xlabel("degrees (reconstructed)")
plt.ylabel("degrees (generated)")


plt.subplot(2,3,5)
plt.title("Azimuth")
plt.scatter(np.array(clean_mc.get_clusterdf()['Azimuth']) * 180 / np.pi, np.array(clean_test.get_clusterdf()['Azimuth']) * 180 / np.pi, s=5)
plt.xlabel("degrees (reconstructed)")
plt.ylabel("degrees (generated)")

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b9267573af44> in <module>
#      26 plt.title("dEdx")
#      27 #plt.scatter(np.array(mc.get_eventdf()['dEdx'])/100, np.array(test.get_eventdf()['dEdx'])/100, s=5)
# ---> 28 plt.scatter(clean_test.get_eventdf()['dEdx']/100, clean_mc.get_eventdf()['dEdx']/100, s=5)
#      29 plt.xlabel("MeV/cm (reconstructed)")
#      30 plt.ylabel("MeV/cm (generated)")
#
# ~/opt/anaconda3/envs/UROP/lib/python3.9/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/opt/anaconda3/envs/UROP/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/envs/UROP/lib/python3.9/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/opt/anaconda3/envs/UROP/lib/python3.9/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4439         y = np.ma.ravel(y)
#    4440         if x.size != y.size:
# -> 4441             raise ValueError("x and y must be the same size")
#    4442
#    4443         if s is None:
#
# ValueError: x and y must be the same size

# %%
clean_mc.clusterdf

# %%
plt.hist(test.get_eventdf()['dEdx'], np.linspace(0,2000,20), histtype='step')
plt.figure()
plt.hist(data.get_clusterdf().head(5)['dEdx'], histtype='step')
