# %%
# %run MonteCarlo.ipynb
mc = MonteCarlo(100, "isotropic")

mc.get_clusterdf()
# Out:
#     Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0         0       5         5  6.625862e+03         0.0  1.097667  1.295423
# 1         1       7         7  1.031227e+05         0.0  0.969235  1.404413
# 2         2       9         9  1.390939e+05         0.0  0.973215  1.263139
# 3         3       5         5  1.606985e+05         0.0  1.247225  1.048153
# 4         4       3         3  1.705753e+05         0.0  1.266036  0.836819
# ..      ...     ...       ...           ...         ...       ...       ...
# 81       81       3         3  2.588622e+06         0.0  1.385646  1.086384
# 82       82      12        12  2.594882e+06         0.0  1.033539  0.729762
# 83       83      10        10  2.680852e+06         0.0  1.025166  1.321775
# 84       84      10        10  2.688600e+06         0.0  0.973928  1.064693
# 85       85      13        13  2.699905e+06         0.0  0.973810  0.644847
#
#      Azimuth  ExtraCh  MissingCh  \
# ...

# %%
df = mc.get_eventdf()[(mc.get_eventdf()['Cluster'] >= 10) & (mc.get_eventdf()['Cluster'] < 20)]
da = DataAnalysis()
da.set_eventdf(df)
da.make_clusterdf(basicfit=True)
da.get_clusterdf()
# Out:
#    Cluster  Events  Channels      StartTime  TimeSpread     NRMSE    Zenith  \
# 0       10      10        10  393608.394005         0.0  1.005196  1.239123
# 1       11       6         6  473346.682584         0.0  0.863647  1.001258
# 2       12       9         9  500212.518299         0.0  0.673522  1.251838
# 3       13       8         8  548544.368509         0.0  0.619077  1.570796
# 4       14       9         9  551914.437982         0.0  0.726446  0.527063
# 5       15       7         7  569734.522692         0.0  0.837578  1.245170
# 6       16       8         8  578574.041704         0.0  0.918018  1.247920
# 7       17       7         7  581682.670713         0.0  0.849043  0.831056
# 8       18       4         4  613722.275880         0.0  0.782477  1.327319
# 9       19       8         8  633055.558891         0.0  0.973435  0.746033
#
#     Azimuth  ExtraCh  MissingCh  \
# 0 -0.862892        1          1
# 1 -0.097492        1          0
# ...

# %%
points = np.array([mc.iso_track()[:3] for i in range(200)])

plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.set_proj_type('ortho')

ax.scatter3D(*points.T)

plt.xlim([-400,400])
plt.ylim([-400,400])
ax.set_zlim([-1000,1000])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.view_init(15, 45)

plt.show()
