# %%
# %run DataAnalysis.ipynb

# %%
mc = DataAnalysis(load=True, eventfile="./data/mc/MC_eventdf.csv", clusterfile="./data/mc/MC_clusterdf.csv")
naive = DataAnalysis(load=True, eventfile="./data/mc/eventdf.csv", clusterfile="./data/mc/Basic_clusterdf.csv")
moo = DataAnalysis(load=True, eventfile="./data/mc/eventdf.csv", clusterfile="./data/mc/clusterdf.csv")

# %%
mc.get_clusterdf()
# Out:
#       Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0           0       4         4  5.038257e+02         0.0  1.110934  1.168158
# 1           1       5         5  9.857393e+02         0.0  1.071303  1.075544
# 2           2       6         6  1.086902e+03         0.0  1.076983  1.138830
# 3           3       6         6  1.484747e+03         0.0  0.898528  1.465150
# 4           4      10        10  2.014796e+03         0.0  1.022612  1.071196
# ...       ...     ...       ...           ...         ...       ...       ...
# 8578     8578       5         5  2.757517e+06         0.0  1.080527  1.419253
# 8579     8579       9         9  2.757945e+06         0.0  0.989090  0.708669
# 8580     8580       9         9  2.758278e+06         0.0  1.086753  1.279212
# 8581     8581      10        10  2.758515e+06         0.0  0.970217  0.714100
# 8582     8582       4         4  2.758802e+06         0.0  0.922700  1.538498
#
# ...

# %%
naive.get_clusterdf()
# Out:
#       Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0           0       4         4  5.038257e+02         0.0  0.855644  1.190878
# 1        6801       5         5  2.187026e+06         0.0  0.764968  1.570796
# 2        6802      10        10  2.187819e+06         0.0  0.920904  1.443471
# 3        6803       3         3  2.188068e+06         0.0  1.042783  0.821666
# 4        6804       3         3  2.188101e+06         0.0  0.000000  1.570796
# ...       ...     ...       ...           ...         ...       ...       ...
# 8578     3396       5         5  1.105083e+06         0.0  0.586866  1.415673
# 8579     3397       8         8  1.105095e+06         0.0  0.686034  0.861442
# 8580     3398       6         6  1.105305e+06         0.0  0.831029  0.624044
# 8581     3399       4         4  1.105496e+06         0.0  0.959948  1.265121
# 8582     3400       9         9  1.105510e+06         0.0  0.814372  1.337277
#
# ...

# %%
moo.get_clusterdf()
# Out:
#       Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0           0       4         4  5.038257e+02         0.0  0.995182  1.197026
# 1        6801       5         5  2.187026e+06         0.0  0.823890  1.531294
# 2        6802      10        10  2.187819e+06         0.0  0.920904  1.443471
# 3        6803       3         3  2.188068e+06         0.0  1.570832  0.859449
# 4        6804       3         3  2.188101e+06         0.0  1.118554  1.339167
# ...       ...     ...       ...           ...         ...       ...       ...
# 8578     3396       5         5  1.105083e+06         0.0  0.952674  1.428709
# 8579     3397       8         8  1.105095e+06         0.0  0.686034  0.861442
# 8580     3398       6         6  1.105305e+06         0.0  0.863295  0.641382
# 8581     3399       4         4  1.105496e+06         0.0  1.110556  1.208002
# 8582     3400       9         9  1.105510e+06         0.0  0.896824  1.341982
#
# ...

# %%
naive.clusterdf = naive.get_clusterdf().sort_values(by=['Cluster'])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-fc1fa76b2de2> in <module>
# ----> 1 self.clusterdf.reset_index(drop=True)
#
# NameError: name 'self' is not defined

# %%
# %run MonteCarlo.ipynb

# %%
mc = MonteCarlo(10, "isotropic")

# %%
mc.get_clusterdf()
# Out:
#    Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0       4         4  2.753191e+05         0.0  1.557668  0.740806
# 1        1       5         5  7.754904e+05         0.0  1.171950  1.448742
# 2        2      13        13  1.037014e+06         0.0  1.006973  0.650857
# 3        3       6         6  1.410417e+06         0.0  1.169813  0.955014
# 4        4       6         6  1.502737e+06         0.0  0.586006  1.415456
# 5        5      11        11  1.631835e+06         0.0  1.001467  1.284214
# 6        6       5         5  2.128924e+06         0.0  1.031110  0.957483
# 7        7       8         8  2.491121e+06         0.0  0.995609  0.432823
#
#     Azimuth  ExtraCh  MissingCh  \
# 0  0.015301        0          0
# 1 -0.630973        0          0
# 2  0.236300        0          0
# 3  1.124235        0          0
# 4 -0.150684        0          0
# 5 -0.490125        0          0
# 6 -0.229157        0          0
# ...

# %%
mc.get_clusterdf()[mc.get_clusterdf()['Cluster'] == 3]['Fitline'].iloc[0]
# Out:
# array([-148.414349, -103.032084, -269.277608,   -0.352542,   -0.736271,
#           0.577597])

# %%
mc.save_eventdf("./testeventdf.csv")
mc.save_clusterdf("./testclusterdf.csv")

# %%
loadmc = DataAnalysis(load=True, eventfile='./testeventdf.csv', clusterfile='./testclusterdf.csv')

# %%
rawline = loadmc.get_clusterdf()['Fitline'][0]
rawline
# Out:
# '[ 1.87656321e+02 -4.67292610e+01  2.04489209e+02  5.97290000e-02\n -4.64515000e-01 -8.83549000e-01]'

# %%
loadmc.get_clusterdf()['Fitline'] = loadmc.get_clusterdf()['Fitline'].apply(lambda rawline: np.array(rawline.strip('[]').split(), dtype=np.float64))

# %%
loadmc.get_clusterdf()
# Out:
#    Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0       5         5  2.285281e+05         0.0  0.870318  0.487410
# 1        1       9         9  3.501791e+05         0.0  0.913920  1.383607
# 2        2      10        10  5.786660e+05         0.0  1.003898  0.604522
# 3        3       7         7  1.298832e+06         0.0  1.151965  0.977934
# 4        4       3         3  1.596436e+06         0.0  1.770693  1.557601
# 5        5       9         9  1.961104e+06         0.0  1.005788  1.384210
# 6        6       9         9  2.021820e+06         0.0  1.077953  0.701080
# 7        7       7         7  2.118678e+06         0.0  1.101836  1.283256
# 8        8       8         8  2.495576e+06         0.0  0.983343  1.449978
#
#     Azimuth  ExtraCh  MissingCh  \
# 0 -1.442914        0          0
# 1  0.921312        0          0
# 2  0.491808        0          0
# 3 -0.873518        0          0
# 4  0.439105        0          0
# ...
