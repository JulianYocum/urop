# %%
import numpy as np
import pandas as pd
import scipy as sc
import uproot as up

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
events1 = up.open('WorkingDir/JulianUrop/ds3564/ds3564Tower1.root')['tree']
events2 = up.open('WorkingDir/JulianUrop/ds3564/ds3564Tower2.root')['tree']
events3 = up.open('WorkingDir/JulianUrop/ds3564/ds3564Tower3.root')['tree']

# %%
data1 = events1.pandas.df()
data2 = events2.pandas.df()
data3 = events3.pandas.df()

# %%
frames = [data1, data2, data3]
#concatenate the frames!
alldata = pd.concat(frames)

# %%
alldata
# Out:
#           Run  Channel       Time  NumPulses   OFdelay  MaxPosInWindow  \
# entry
# 0      350259        4    201.712          1  3.175603            3162
# 1      350259       32    334.408          1  3.173095            3164
# 2      350259       23   1922.776          1  3.209816            3208
# 3      350259        6   3444.392          1  3.175244            3161
# 4      350259       29   5731.368          1  3.168502            3158
# ...       ...      ...        ...        ...       ...             ...
# 5492   350292      114  56794.440          1  3.167796            3157
# 5493   350292      121  57099.312          1  3.157400            3151
# 5494   350292      110  57219.152          1  3.143980            3136
# 5495   350292      107  57425.824          1  3.150054            3146
# 5496   350292      132  57820.512          1  3.170479            3162
#
#        SelectedEnergy     Baseline  MaxToBaseline      StabAmp
# entry
# ...
