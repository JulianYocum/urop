# %%
import copy
#packages we'll need

# %matplotlib inline 
#this is a ``magic command'' specific to display plots in-line in a jupyter notebook
#normally you would plot by calling a plt.show()


from matplotlib.colors import LogNorm
#need this for the colourbar of the 2D histogram


# %run MonteCarlo.ipynb

# %%
mc = MonteCarlo(10, "isotropic")

# %%
data = DataAnalysis()
data.set_eventdf(mc.get_eventdf())
data.make_clusterdf(basicfit=True)

# %%
plt.figure()
plt.title("Monte Carlo Crystal Path Length")
plt.xlabel("Path Length in Crystal (Angstroms)")
plt.ylabel("Counts")

array = plt.hist(np.array(mc.get_eventdf()['PathLength'].values, dtype=np.float64), bins=20)

plt.figure()
plt.title("Basic Fit Crystal Path Length")
plt.xlabel("Path Length in Crystal (Angstroms)")
plt.ylabel("Counts")

array = plt.hist(np.array(data.get_eventdf()['PathLength'].values, dtype=np.float64), bins=20)

# %%
mc.get_clusterdf()
# Out:
#    Cluster  Events  Channels      StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0      10        10   21030.396617         0.0  1.066642  0.731651
# 1        1       8         8   21940.925815         0.0  0.907031  1.403713
# 2        2       7         7   27643.579478         0.0  0.710728  1.375011
# 3        3       8         8   62278.841972         0.0  0.784962  1.185269
# 4        4       6         6   65633.021177         0.0  0.701925  1.153840
# 5        5       8         8   73262.482873         0.0  0.964611  1.255807
# 6        6       9         9   73277.009053         0.0  1.017689  1.328855
# 7        7       9         9   74182.380421         0.0  0.871872  0.986364
# 8        8      12        12  101791.074591         0.0  1.008717  0.813855
#
#     Azimuth  ExtraCh  MissingCh  \
# 0 -1.360383        0          0
# 1 -0.621396        0          0
# 2  0.008635        0          0
# 3 -1.473681        0          0
# 4  1.217543        0          0
# ...

# %%
data.get_clusterdf()
# Out:
#    Cluster  Events  Channels      StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0      10        10   21030.396617         0.0  1.018107  0.741866
# 1        1       8         8   21940.925815         0.0  0.816905  1.424665
# 2        2       7         7   27643.579478         0.0  0.655672  1.403571
# 3        3       8         8   62278.841972         0.0  0.422399  1.204256
# 4        4       6         6   65633.021177         0.0  0.680383  1.161678
# 5        5       8         8   73262.482873         0.0  0.948539  1.262380
# 6        6       9         9   73277.009053         0.0  0.992912  1.343829
# 7        7       9         9   74182.380421         0.0  0.686320  0.980610
# 8        8      12        12  101791.074591         0.0  0.998659  0.822800
#
#     Azimuth  ExtraCh  MissingCh  \
# 0 -1.365987        1          1
# 1 -0.579412        2          0
# 2  0.014536        1          0
# 3  1.570796        0          0
# 4  1.199754        1          0
# ...

# %%
data.channelcollisions(data.get_clusterdf()['Fitline'][7])
# Out:
# ([604, 616, 707, 720, 758, 771],
#  [577, 603, 617],
#  [56.301484298922524,
#   16.17702371560286,
#   47.52610960583862,
#   56.30148429892252,
#   24.65133138438929,
#   56.301484298922524])

# %%
mc.channelcollisions(mc.get_clusterdf()['Fitline'][7])
# Out:
# ([604, 616, 707, 720, 771],
#  [603, 617, 772],
#  [14.754965975084767,
#   52.125541056755154,
#   5.763940665621938,
#   53.787508418415634,
#   0.04852049655133619])

# %%
data.show_cluster(3)

# %%
mc.get_cluster(0)
# Out:
#    Run  Channel          Time  NumPulses  OFdelay  MaxPosInWindow  \
# 0    0      123  21027.196617          1      3.2             3.2
# 1    0      124  21027.196617          1      3.2             3.2
# 2    0      135  21027.196617          1      3.2             3.2
# 3    0      136  21027.196617          1      3.2             3.2
# 4    0      172  21027.196617          1      3.2             3.2
# 5    0      173  21027.196617          1      3.2             3.2
# 6    0      184  21027.196617          1      3.2             3.2
# 7    0      185  21027.196617          1      3.2             3.2
# 8    0      920  21027.196617          1      3.2             3.2
# 9    0      921  21027.196617          1      3.2             3.2
#
#    SelectedEnergy  Baseline  MaxToBaseline  StabAmp  Track       MaxTime  \
# 0             0.0   -2000.0        12000.0      0.0      0  21030.396617
# 1             0.0   -2000.0        12000.0      0.0      0  21030.396617
# ...

# %%
data.get_cluster(0)
# Out:
#    Run  Channel          Time  NumPulses  OFdelay  MaxPosInWindow  \
# 0    0      123  21027.196617          1      3.2             3.2
# 1    0      124  21027.196617          1      3.2             3.2
# 2    0      135  21027.196617          1      3.2             3.2
# 3    0      136  21027.196617          1      3.2             3.2
# 4    0      172  21027.196617          1      3.2             3.2
# 5    0      173  21027.196617          1      3.2             3.2
# 6    0      184  21027.196617          1      3.2             3.2
# 7    0      185  21027.196617          1      3.2             3.2
# 8    0      920  21027.196617          1      3.2             3.2
# 9    0      921  21027.196617          1      3.2             3.2
#
#    SelectedEnergy  Baseline  MaxToBaseline  StabAmp  Track       MaxTime  \
# 0             0.0   -2000.0        12000.0      0.0      0  21030.396617
# 1             0.0   -2000.0        12000.0      0.0      0  21030.396617
# ...

# %%
data.basicfit(data.get_cluster(0))
# Out:
# array([   0.      , -323.4     ,  -58.      ,    0.537974,    0.      ,
#           0.842962])

# %%
data.get_clusterdf()
# Out:
#    Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0        0       4         4    684.111313         0.0  0.884559  0.568032
# 1        1       6         6  14888.244149         0.0  0.716180  1.091493
# 2        2      11        11  21158.179924         0.0  0.717714  1.227934
# 3        3      11        11  43433.014182         0.0  0.685990  0.312327
# 4        4       5         5  48968.588940         0.0  1.104943  1.412104
# 5        5       7         7  53489.364557         0.0  1.134444  0.914462
# 6        6       5         5  74816.013161         0.0  1.020837  0.666441
# 7        7       5         5  92211.654711         0.0  0.840728  1.325181
# 8        8      10        10  95250.500420         0.0  0.919299  1.173401
# 9        9      11        11  97746.636157         0.0  1.004962  1.261940
#
#     Azimuth  ExtraCh  MissingCh  \
# 0 -0.000000        0          0
# 1 -1.202317        0          0
# 2 -0.442169        0          0
# ...
