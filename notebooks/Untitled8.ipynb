# %%
# %run MonteCarlo.ipynb

# %%
mc = MonteCarlo(10000, "iso")

# %%
plt.hist(mc.get_clusterdf()['Azimuth'])

plt.figure()
plt.hist(mc.get_clusterdf()[mc.get_clusterdf()['Channels'] > 5]['Azimuth'])
# Out:
# (array([649., 676., 787., 680., 620., 594., 705., 716., 714., 635.]),
#  array([-1.57023487e+00, -1.25615393e+00, -9.42072989e-01, -6.27992051e-01,
#         -3.13911113e-01,  1.69825946e-04,  3.14250764e-01,  6.28331703e-01,
#          9.42412641e-01,  1.25649358e+00,  1.57057452e+00]),
#  <a list of 10 Patch objects>)

# %%
mc.show_channel(list(range(573, 625)) + list(range(325,365)))
