# %%
# %run MonteCarlo.ipynb

# %%
# box = 3 m
mc1 = MonteCarlo(10000, "flux")
mc1.get_clusterdf()
# Out:
#       Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0           0       8         8  4.764915e+02         0.0  0.904044  1.036734
# 1           1       3         3  1.639296e+03         0.0  1.496468  1.119889
# 2           2       4         4  4.622933e+03         0.0  1.496444  1.469195
# 3           3       8         8  1.092245e+04         0.0  0.874133  1.306115
# 4           4       8         8  1.119451e+04         0.0  1.033895  1.348008
# ...       ...     ...       ...           ...         ...       ...       ...
# 1584     1584      12        12  2.755066e+06         0.0  1.085109  1.068670
# 1585     1585       3         3  2.755686e+06         0.0  1.440029  0.303978
# 1586     1586       5         5  2.755753e+06         0.0  1.024130  1.543483
# 1587     1587       9         9  2.756229e+06         0.0  0.977950  1.138609
# 1588     1588      10        10  2.758777e+06         0.0  1.020144  0.783810
#
# ...

# %%
# %run MonteCarlo.ipynb

# %%
# box = 5 m
mc2 = MonteCarlo(10000, "flux")
mc2.get_clusterdf()
# Out:
#      Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0          0       6         6  4.142726e+03         0.0  1.274418  1.523879
# 1          1       8         8  4.219663e+03         0.0  0.795675  1.561099
# 2          2       4         4  1.027624e+04         0.0  1.003394  1.525996
# 3          3       6         6  1.061731e+04         0.0  0.709035  1.267627
# 4          4       7         7  1.097560e+04         0.0  0.891499  0.549309
# ..       ...     ...       ...           ...         ...       ...       ...
# 664      664       4         4  2.745221e+06         0.0  1.358015  1.084170
# 665      665       5         5  2.747852e+06         0.0  1.291948  1.223707
# 666      666       1         1  2.749114e+06         0.0  0.000000  1.472916
# 667      667       3         3  2.751610e+06         0.0  1.463190  1.252096
# 668      668       7         7  2.759391e+06         0.0  0.997352  0.910039
#
#       Azimuth  ExtraCh  MissingCh
# ...

# %%
# %run MonteCarlo.ipynb

# %%
# box = 7 m
mc3 = MonteCarlo(10000, "flux")
mc3.get_clusterdf()
# Out:
#      Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0          0       7         7  8.498691e+02         0.0  1.091111  1.514075
# 1          1       8         8  5.275756e+03         0.0  0.871572  1.259947
# 2          2      10        10  8.277131e+03         0.0  0.987434  1.460401
# 3          3       3         3  1.962263e+04         0.0  1.404312  1.255857
# 4          4       9         9  2.350101e+04         0.0  1.108742  1.462956
# ..       ...     ...       ...           ...         ...       ...       ...
# 408      408       2         2  2.722860e+06         0.0  0.000000  1.332196
# 409      409      10        10  2.723694e+06         0.0  1.069842  1.500351
# 410      410       5         5  2.726113e+06         0.0  1.073111  1.335418
# 411      411       7         7  2.728366e+06         0.0  0.938553  1.456387
# 412      412       9         9  2.737446e+06         0.0  1.095408  1.499169
#
#       Azimuth  ExtraCh  MissingCh
# ...

# %%
# %run MonteCarlo.ipynb

# %%
# box = 10 m
mc4 = MonteCarlo(10000, "flux")
mc4.get_clusterdf()
# Out:
#      Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0          0       5         5  5.207480e+03         0.0  1.407948  0.649231
# 1          1       5         5  7.241002e+03         0.0  1.197225  1.473208
# 2          2       9         9  2.249993e+04         0.0  1.154233  1.489836
# 3          3       4         4  3.393553e+04         0.0  1.356018  1.483868
# 4          4       1         1  3.709875e+04         0.0  0.000000  1.490571
# ..       ...     ...       ...           ...         ...       ...       ...
# 204      204       2         2  2.696526e+06         0.0  0.000000  1.550364
# 205      205       5         5  2.720666e+06         0.0  0.890092  1.530417
# 206      206       7         7  2.740165e+06         0.0  1.008477  0.559336
# 207      207       1         1  2.743103e+06         0.0  0.000000  0.942395
# 208      208      11        11  2.743736e+06         0.0  1.083857  0.625367
#
#       Azimuth  ExtraCh  MissingCh
# ...

# %%
# %run MonteCarlo.ipynb

# %%
# box = 12 m
mc5 = MonteCarlo(10000, "flux")
mc5.get_clusterdf()
# Out:
#      Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0          0       7         7  3.372676e+03         0.0  0.890853  1.486146
# 1          1       9         9  4.108880e+03         0.0  0.899299  1.205616
# 2          2      10        10  5.377446e+03         0.0  0.779229  1.340795
# 3          3       6         6  7.243633e+04         0.0  0.933953  1.495962
# 4          4       7         7  1.016220e+05         0.0  0.969599  1.082776
# ..       ...     ...       ...           ...         ...       ...       ...
# 139      139       2         2  2.707277e+06         0.0  0.000000  1.348891
# 140      140       8         8  2.712227e+06         0.0  0.967963  0.874891
# 141      141      10        10  2.714018e+06         0.0  0.891070  1.521241
# 142      142      10        10  2.733442e+06         0.0  1.013367  1.216026
# 143      143       8         8  2.738759e+06         0.0  1.008734  0.978562
#
#       Azimuth  ExtraCh  MissingCh
# ...

# %%
print(len(mc1.get_clusterdf()[mc1.get_clusterdf()['Channels'] >= 3]))
print(len(mc2.get_clusterdf()[mc2.get_clusterdf()['Channels'] >= 3]))
print(len(mc3.get_clusterdf()[mc3.get_clusterdf()['Channels'] >= 3]))
print(len(mc4.get_clusterdf()[mc4.get_clusterdf()['Channels'] >= 3]))
print(len(mc5.get_clusterdf()[mc4.get_clusterdf()['Channels'] >= 3]))
# Out:
# 1332
# 558
# 357
# 172
# 119
# /Users/julianyocum/opt/anaconda3/envs/UROP/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
print(len(mc1.get_clusterdf()[mc1.get_clusterdf()['Channels'] >= 5]))
print(len(mc2.get_clusterdf()[mc2.get_clusterdf()['Channels'] >= 5]))
print(len(mc3.get_clusterdf()[mc3.get_clusterdf()['Channels'] >= 5]))
print(len(mc4.get_clusterdf()[mc4.get_clusterdf()['Channels'] >= 5]))
print(len(mc5.get_clusterdf()[mc4.get_clusterdf()['Channels'] >= 5]))
# Out:
# 1054
# 446
# 295
# 138
# 96
# /Users/julianyocum/opt/anaconda3/envs/UROP/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
xvals=np.array([3,5,7,10, 12])
yvals=np.array([1589,669,413,209, 144])
plt.title('Exposure of CUORE')
plt.ylabel('Exposure ( m$^2\cdot$Sr)')
plt.xlabel('Area of Reference Surface')
plt.scatter(4*np.pi*xvals**2, (yvals/10000.)*4*np.pi*xvals**2)
plt.errorbar(4*np.pi*xvals**2, (yvals/10000.)*4*np.pi*xvals**2,yerr=(np.sqrt(yvals)/10000)*4*np.pi*xvals**2,linestyle='none')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
xvals=np.arange(3,21)
yvals=np.array([13598,12415,11021,9482, 7335, 5194, 3040, 1665, 859, 434, 222, 104, 45, 15, 4, 2, 1, 0])
plt.title('Exposure of CUORE')
plt.ylabel('Exposure ( m$^2\cdot$Sr)')
plt.xlabel('Channel threshold')
plt.scatter(xvals, (yvals/1000000.)*4*np.pi*12**2 )
array = plt.errorbar(xvals, (yvals/1000000.)*4*np.pi*12**2,yerr=(np.sqrt(yvals)/1000000)*4*np.pi*12**2,linestyle='none')

# %%
values = (yvals/1000000.)*4*np.pi*12**2
error = (np.sqrt(yvals)/1000000)*4*np.pi*12**2

for i in range(3):
    print(str(values[i]) + " +/- " + str(error[i]))
# Out:
# 24.60636109642407 +/- 0.21101332193302785
# 22.465654729526758 +/- 0.20162562102388384
# 19.943131757882753 +/- 0.18996905280281665

# %%
For 3 or more channels, detected: 13598
For 4 or more channels, detected: 12415
For 5 or more channels, detected: 11021
For 6 or more channels, detected: 9482
For 7 or more channels, detected: 7335
For 8 or more channels, detected: 5194
For 9 or more channels, detected: 3040
For 10 or more channels, detected: 1665
For 11 or more channels, detected: 859
For 12 or more channels, detected: 434
For 13 or more channels, detected: 222
For 14 or more channels, detected: 104
For 15 or more channels, detected: 45
For 16 or more channels, detected: 15
For 17 or more channels, detected: 4
For 18 or more channels, detected: 2
For 19 or more channels, detected: 1
For 20 or more channels, detected: 0

# %%
# %run DataAnalysis.ipynb
#flux_data = DataAnalysis()
#flux_data.load_clusterdf("data/flux/flux_clusterdf.csv")

flux_data10 = DataAnalysis()
flux_data10.load_clusterdf("data/flux/flux_clusterdf_10M.csv")

# %%
clean_data = flux_data10.get_clusterdf()[np.isfinite(flux_data10.get_clusterdf()['Azimuth'].values)]

# %%
len(flux_data10.get_clusterdf())
# Out:
# 9873017

# %%
for c in range(3, 22):
    detections = len(flux_data10.get_clusterdf()[flux_data10.get_clusterdf()['Channels'] >= c]['Channels'])
    print(str(c) + ": " + str(detections))

# %%
xvals=np.arange(3,22)
yvals=np.array([137091,125261,111187,95674, 74008, 52848, 31737, 17247, 8808, 4314, 2020, 901, 411, 152, 52, 21, 9, 3, 3])
plt.title('Exposure of CUORE')
plt.ylabel('Exposure ( m$^2\cdot$Sr)')
plt.xlabel('Channel threshold')
plt.scatter(xvals, (yvals/10000000.)*4*np.pi*12**2 )
array = plt.errorbar(xvals, (yvals/10000000.)*4*np.pi*12**2,yerr=(np.sqrt(yvals)/10000000)*4*np.pi*12**2,linestyle='none')

# %%
values = (yvals/10000000.)*4*np.pi*12**2
error = (np.sqrt(yvals)/10000000)*4*np.pi*12**2

for i in range(3):
    print(str(values[i]) + " +/- " + str(error[i]))
# Out:
# 24.807402920060834 +/- 0.06700031249669193
# 22.66669655316352 +/- 0.06404427200507391
# 20.11992551278205 +/- 0.06033917422759152

# %%
filter_data =  flux_data10.get_clusterdf()[flux_data10.get_clusterdf()['Channels'] > 5]
filter_data
# Out:
#         Cluster  Events  Channels    StartTime TimeSpread     NRMSE    Zenith  \
# 139         139    10.0      10.0   1.6936e+06          0  0.993384  1.545019
# 254         254     9.0       9.0  3.01051e+06          0  0.905155  1.500682
# 388         388     6.0       6.0  4.39991e+06          0  0.712134  1.382016
# 553         553     6.0       6.0  6.26348e+06          0  0.910379  1.446077
# 849         849     8.0       8.0  9.47796e+06          0  1.074726  1.476463
# ...         ...     ...       ...          ...        ...       ...       ...
# 9872669  199652    10.0      10.0  2.20408e+09          0  1.063712  1.324786
# 9872690  199673     6.0       6.0  2.20432e+09          0  0.769852  1.394860
# 9872781  199764     6.0       6.0  2.20541e+09          0  0.834086  1.560966
# 9872856  199839     9.0       9.0  2.20627e+09          0  0.761819  1.444902
# 9872893  199876     6.0       6.0  2.20661e+09          0  0.878646  1.482486
#
# ...

# %%
array1 = plt.hist(filter_data['Azimuth'], bins=31)
plt.figure()
array2 = plt.hist(clean_data['Azimuth'], bins=31)

# %%
array, _, _ = plt.hist(np.cos(filter_data['Zenith'].values), np.linspace(0, 1, 30))
plt.figure()
plt.hist(np.cos(clean_data['Zenith'].values), np.linspace(0, 1, 30))
# Out:
# (array([340292., 340274., 341071., 341171., 340263., 340975., 338801.,
#         340971., 340537., 340092., 339675., 339848., 340407., 340069.,
#         340600., 340685., 340135., 340064., 340991., 341283., 340547.,
#         340658., 340513., 340726., 339871., 340156., 340036., 341184.,
#         341114.]),
#  array([0.        , 0.03448276, 0.06896552, 0.10344828, 0.13793103,
#         0.17241379, 0.20689655, 0.24137931, 0.27586207, 0.31034483,
#         0.34482759, 0.37931034, 0.4137931 , 0.44827586, 0.48275862,
#         0.51724138, 0.55172414, 0.5862069 , 0.62068966, 0.65517241,
#         0.68965517, 0.72413793, 0.75862069, 0.79310345, 0.82758621,
#         0.86206897, 0.89655172, 0.93103448, 0.96551724, 1.        ]),
#  <a list of 29 Patch objects>)

# %%
fcounts, xbins, ybins, _ = plt.hist2d(filter_data['Azimuth'], filter_data['Zenith'], np.linspace(0, np.pi/2, 20))
plt.figure()
counts, xbins, ybins, _ = plt.hist2d(clean_data['Azimuth'], clean_data['Zenith'], np.linspace(0,np.pi/2, 20))

# %%
bins = [36,38]
hist, xedges, yedges = np.histogram2d(filter_data['Azimuth'].values, np.cos(filter_data['Zenith'].values), bins=bins, range=[[-np.pi/2, np.pi/2], [0, 1]])
chist, xedges, yedges = np.histogram2d(clean_data['Azimuth'].values, np.cos(clean_data['Zenith'].values), bins=bins, range=[[-np.pi/2, np.pi/2], [0, 1]])

hist = hist /  chist * 10**2
#hist = hist /  len(clean_data) * 10**2
np.save('data/exposure.npy', hist)

# Construct arrays for the anchor positions of the 16 bars.
xpos, ypos = np.meshgrid(xedges[:-1] + np.pi / bins[0] * 1/2, yedges[:-1] + 1 / bins[1] * 1/2, indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

# Construct arrays with the dimensions for the 16 bars.
dx = np.pi / bins[0] * np.ones_like(zpos)
dy = 1/bins[1] * np.ones_like(zpos)


dz = hist.ravel()

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(projection='3d')

ax.set_xlabel('Azimuth')
ax.set_ylabel('Zenith')
ax.set_zlabel('Exposure')



ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')


ax.view_init(45, 60)

plt.show()

# %%
xedges
# Out:
# array([-1.57079633, -1.48352986, -1.3962634 , -1.30899694, -1.22173048,
#        -1.13446401, -1.04719755, -0.95993109, -0.87266463, -0.78539816,
#        -0.6981317 , -0.61086524, -0.52359878, -0.43633231, -0.34906585,
#        -0.26179939, -0.17453293, -0.08726646,  0.        ,  0.08726646,
#         0.17453293,  0.26179939,  0.34906585,  0.43633231,  0.52359878,
#         0.61086524,  0.6981317 ,  0.78539816,  0.87266463,  0.95993109,
#         1.04719755,  1.13446401,  1.22173048,  1.30899694,  1.3962634 ,
#         1.48352986,  1.57079633])

# %%
hist
# Out:
# array([[3.15346882, 2.81497677, 3.33931282, ..., 0.2367688 , 0.25143176,
#         0.1372872 ],
#        [2.77012128, 2.86346659, 2.65817527, ..., 0.24807056, 0.17879246,
#         0.1399776 ],
#        [3.13233062, 3.51147174, 3.1300813 , ..., 0.16547159, 0.20778501,
#         0.29158567],
#        ...,
#        [3.5680369 , 3.44637441, 3.16162442, ..., 0.20920502, 0.29453015,
#         0.19220209],
#        [3.30195115, 2.99016931, 2.76864035, ..., 0.1786205 , 0.20601566,
#         0.18158961],
#        [2.78690868, 2.79602964, 3.00266592, ..., 0.19361084, 0.20871017,
#         0.21984062]])

# %%
def get_exposure(hist, bins, phi, theta):
    xedges = np.linspace(0,np.pi/2,bins[0]+1)
    yedges = np.linspace(0,1, bins[1]+1)
    
    i_index = 0
    for i in range(bins[0]):
        if phi < xedges[i+1]:
            i_index = i
            break
            
    j_index = 0
    for j in range(bins[1]):
        if theta < yedges[j+1]:
            j_index = j
            break
            
    #print(i_index, j_index)
            
    return hist[i_index][j_index]

# %%
get_exposure(hist, [15,15], np.pi/4, .5)
# Out:
# 7.63069703328462

# %%
xpos = (xedges + xedges[1]/2)[:-1]
ypos = (yedges + yedges[1]/2)[:-1]

phis = np.sum(hist, axis=1)
thetas = np.sum(hist, axis=0)

plt.figure()
plt.scatter(xpos, phis)
plt.figure()
plt.scatter(ypos, thetas)

# %%
xedges
# Out:
# array([0.        , 0.10471976, 0.20943951, 0.31415927, 0.41887902,
#        0.52359878, 0.62831853, 0.73303829, 0.83775804, 0.9424778 ,
#        1.04719755, 1.15191731, 1.25663706, 1.36135682, 1.46607657,
#        1.57079633])
