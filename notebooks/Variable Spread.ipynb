# %%
import copy
import time
#packages we'll need

# %matplotlib inline 
#this is a ``magic command'' specific to display plots in-line in a jupyter notebook
#normally you would plot by calling a plt.show()


from matplotlib.colors import LogNorm
#need this for the colourbar of the 2D histogram

# %%
# %run DataAnalysis.ipynb
data1 = DataAnalysis(auto=True)
data1.get_clusterdf()
# Out:
#      Cluster  Events  Channels    StartTime  TimeSpread         NRMSE  \
# 0          0       5         5     7194.345       0.494  5.870382e-01
# 1          1       5         5    37039.429       0.846  8.988934e-01
# 2          2       9         9    42897.221       0.832  8.404473e-01
# 3          3       5         5    62388.310       0.590  6.975745e-01
# 4          4       5         5    73675.640       0.778  6.030657e-01
# ..       ...     ...       ...          ...         ...           ...
# 278      278       5         3  2710760.519       0.903  1.272564e+00
# 279      279       5         2  2710763.342       0.089  2.813894e-15
# 280      280       7         7  2728511.764       0.730  6.414477e-01
# 281      281       7         7  2739741.710       0.575  1.072754e+00
# 282      282       6         6  2747006.328       0.537  7.203354e-01
#
#        Zenith   Azimuth  ExtraCh  MissingCh
# 0    0.405188 -0.222811        0          1
# ...

# %%
# %run DataAnalysis.ipynb
data2 = DataAnalysis(auto=True)
data2.get_clusterdf()
# Out:
#      Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0          0       5         5  7.194281e+03    0.071746  0.587038  0.405188
# 1          1       5         5  3.703957e+04    0.233769  0.898893  0.743109
# 2          2       9         9  4.289679e+04    0.664183  0.840447  0.770941
# 3          3       5         5  6.238830e+04    0.079678  0.697575  0.770401
# 4          4       5         5  7.367581e+04    0.217087  0.603066  0.426780
# ..       ...     ...       ...           ...         ...       ...       ...
# 273      273       5         3  2.710754e+06    2.644191  1.416206  0.658020
# 274      274       5         5  2.710759e+06    0.119840  1.619646  0.674544
# 275      275       7         7  2.728512e+06    0.199083  0.641448  0.564814
# 276      276       7         7  2.739742e+06    0.106825  1.072754  0.647712
# 277      277       6         6  2.747006e+06    0.084028  0.720335  1.150738
#
#       Azimuth  ExtraCh  MissingCh
# ...

# %%
# %run DataAnalysis.ipynb
data3 = DataAnalysis(auto=True)
data3.get_clusterdf()
# Out:
#      Cluster  Events  Channels    StartTime  TimeSpread     NRMSE    Zenith  \
# 0          0       5         5     7191.128       0.024  0.587038  0.405188
# 1          1       5         5    37036.432       0.064  0.898893  0.743109
# 2          2       9         9    42893.584       0.680  0.840447  0.770941
# 3          3       5         5    62385.168       0.024  0.697575  0.770401
# 4          4       5         5    73672.640       0.040  0.603066  0.426780
# ..       ...     ...       ...          ...         ...       ...       ...
# 276      276       5         3  2710750.376       2.600  1.416206  0.658020
# 277      277       5         5  2710755.464       0.144  1.619646  0.674544
# 278      278       7         7  2728508.784       0.032  0.641448  0.564814
# 279      279       7         7  2739738.720       0.048  1.072754  0.647712
# 280      280       6         6  2747003.208       0.016  0.720335  1.150738
#
#       Azimuth  ExtraCh  MissingCh
# ...

# %%
print("Time + MaxPosInWindow: " + str(np.mean(data1.get_clusterdf()['TimeSpread'])))
print("Time + OFdelay: " + str(np.mean(data2.get_clusterdf()['TimeSpread'])))
print("Time: " + str(np.mean(data3.get_clusterdf()['TimeSpread'])))
# Out:
# Time + MaxPosInWindow: 1.0018480565386005
# Time + OFdelay: 0.6917760135320187
# Time: 0.5557010676206462

# %%
print("Cluster rate: " + str(data1.get_clusterrate()))
print("Cluster rate: " + str(data2.get_clusterrate()))
print("Cluster rate: " + str(data3.get_clusterrate()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7f3ef7999173> in <module>
# ----> 1 print("Cluster rate: " + str(data1.get_clusterrate()))
#       2 print("Cluster rate: " + str(data2.get_clusterrate()))
#       3 print("Cluster rate: " + str(data3.get_clusterrate()))
#
# NameError: name 'data1' is not defined

# %%
#copy.deepcopy(data1).filter_clusterdf(2.5, 5)
array = plt.hist(data1.get_clusterdf()["TimeSpread"],np.linspace(0,10,50), histtype='step')
plt.title("Time Spread ('Time' + 'MaxPosInWindow')", fontsize=16)
plt.xlabel("Time Spread (s)", fontsize=14)
plt.ylabel("Occurance", fontsize=14)

plt.savefig('plots/timespreads/Time_MaxPos.pdf',bbox_inches = "tight")
plt.savefig('plots/timespreads/Time_MaxPos.png',dpi=300,bbox_inches = "tight")

plt.figure()
array = plt.hist(data2.get_clusterdf()["TimeSpread"],np.linspace(0,10,50), histtype='step')
plt.title("Time Spread ('Time' + 'OFdelay')", fontsize=16)
plt.xlabel("Time Spread (s)", fontsize=14)
plt.ylabel("Occurance", fontsize=14)

plt.savefig('plots/timespreads/Time_OFdelay.pdf',bbox_inches = "tight")
plt.savefig('plots/timespreads/Time_OFdelay.png',dpi=300,bbox_inches = "tight")

plt.figure()
array = plt.hist(data3.get_clusterdf()["TimeSpread"],np.linspace(0,10,50), histtype='step')
plt.title("Time Spread ('Time')", fontsize=16)
plt.xlabel("Time Spread (s)", fontsize=14)
plt.ylabel("Occurance", fontsize=14)

plt.savefig('plots/timespreads/Time.pdf',bbox_inches = "tight")
plt.savefig('plots/timespreads/Time.png',dpi=300,bbox_inches = "tight")
