# %%
# %run new_DataAnalysis.ipynb

# %%
da = testDataAnalysis()

# %%
da.load_data()

# %%
array = plt.hist(da.get_eventdf()['SelectedEnergy'].values, np.linspace(0,100000, 500))
plt.yscale("log")

# %%
array = plt.hist(da.get_eventdf()['Baseline'].values + da.get_eventdf()['MaxToBaseline'].values, np.linspace(0,10000, 500))
plt.yscale("log")

# %%
da.get_eventdf()[da.get_eventdf()['IsSaturated'] == False]
# Out:
#            Run  Channel         Time  NumPulses   OFdelay  MaxPosInWindow  \
# entry
# 0       350259        4      201.712          1  3.175603           3.162
# 1       350259       32      334.408          1  3.173095           3.164
# 2       350259       23     1922.776          1  3.209816           3.208
# 3       350259        6     3444.392          1  3.175244           3.161
# 4       350259       29     5731.368          1  3.168502           3.158
# ...        ...      ...          ...        ...       ...             ...
# 629554  350292      971  2754764.528          1  3.166504           3.152
# 629564  350292      951  2756635.288          1  3.148618           3.147
# 629568  350292      973  2756792.984          1  3.142149           3.140
# 629576  350292      937  2757653.128          1  3.177405           3.176
# 629579  350292      985  2758780.112          1  3.179346           3.171
#
# ...

# %%
da.eventdf[(da.eventdf['SelectedEnergy']) < 25000]
# Out:
#            Run  Channel         Time  NumPulses   OFdelay  MaxPosInWindow  \
# entry
# 0       350259        4      201.712          1  3.175603           3.162
# 1       350259       32      334.408          1  3.173095           3.164
# 2       350259       23     1922.776          1  3.209816           3.208
# 3       350259        6     3444.392          1  3.175244           3.161
# 4       350259       29     5731.368          1  3.168502           3.158
# ...        ...      ...          ...        ...       ...             ...
# 629554  350292      971  2754764.528          1  3.166504           3.152
# 629564  350292      951  2756635.288          1  3.148618           3.147
# 629568  350292      973  2756792.984          1  3.142149           3.140
# 629576  350292      937  2757653.128          1  3.177405           3.176
# 629579  350292      985  2758780.112          1  3.179346           3.171
#
# ...

# %%
da.filter_baseline()

# %%
array = plt.hist(da.get_eventdf()['SelectedEnergy'].values, np.linspace(0,40000, 500))
plt.yscale("log")
