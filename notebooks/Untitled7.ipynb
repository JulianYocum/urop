# %%
# %run DataAnalysis.ipynb

# %%
data = DataAnalysis(auto=True)

# %%
data.get_eventdf()
# Out:
#          Run  Channel         Time  NumPulses   OFdelay  MaxPosInWindow  \
# 4     350259      390     7191.136          1  3.153082           3.209
# 5     350259      376     7191.152          1  3.175950           3.328
# 6     350259      375     7191.128          1  3.152633           3.644
# 7     350259       27     7191.136          1  3.175879           3.637
# 8     350259       28     7191.152          1  3.200379           3.687
# ...      ...      ...          ...        ...       ...             ...
# 4259  350292      222  2747003.208          1  3.147254           3.121
# 4260  350292      355  2747003.224          1  3.152207           3.451
# 4261  350292      236  2747003.224          1  3.172547           3.519
# 4262  350292      302  2747003.224          1  3.169739           3.527
# 4263  350292      781  2747003.224          1  3.211941           3.641
#
#       SelectedEnergy     Baseline  MaxToBaseline       StabAmp      MaxTime  \
# ...

# %%
data.get_clusterdf().head(10)
# Out:
#     Cluster  Events  Channels  StartTime  TimeSpread     NRMSE    Zenith  \
# 0         0       5         5   7194.345       0.494  0.587038  0.405188
# 1         1       5         5  37039.429       0.846  0.898893  0.743109
# 2         2       9         9  42897.221       0.832  0.840447  0.770940
# 3         3       5         5  62388.310       0.590  0.697575  0.770400
# 4         4       5         5  73675.640       0.778  0.603066  0.426781
# 5         5       5         5  76696.204       0.526  0.714815  0.644003
# 6         6       8         8  88352.211       0.822  0.544042  0.671171
# 10       10      11         6  90228.774       2.136  1.377169  0.341830
# 11       11       7         5  90232.278       0.860  2.426260  1.540281
# 12       12       5         5  94229.597       0.935  1.847424  0.833785
#
#      Azimuth  ExtraCh  MissingCh  \
# 0  -0.222810        1          0
# 1  -0.733421        2          0
# 2  -1.345468        3          0
# ...

# %%
len(data.get_eventdf()[(data.get_eventdf()['Hit'] == True) & (data.get_eventdf()['Cluster'].isin(data.get_clusterdf()['Cluster']))]) / len(data.get_eventdf()[data.get_eventdf()['Cluster'].isin(data.get_clusterdf()['Cluster'])])
# Out:
# 0.8221722003376477
