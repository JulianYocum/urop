# %%
data0 = DataAnalysis(load=True, eventfile='data/variable/eventdf_Time_MaxPos.csv', clusterfile='data/variable/clusterdf_Time_MaxPos.csv')

# %%
data1 = DataAnalysis(load=True, eventfile='data/variable/eventdf_Time_OFdelay.csv', clusterfile='data/variable/clusterdf_Time_OFdelay.csv')

# %%
data2 = DataAnalysis(load=True, eventfile='data/variable/eventdf_Time.csv', clusterfile='data/variable/clusterdf_Time.csv')

# %%
data0.filter_clusterdf(2.5, 5)
data1.filter_clusterdf(2.5, 5)
data2.filter_clusterdf(2.5, 5)

# %%
print("Cluster rate: " + str(data0.get_clusterrate()))
print("Cluster rate: " + str(data1.get_clusterrate()))
print("Cluster rate: " + str(data2.get_clusterrate()))
# Out:
# Cluster rate: 9.291061657381294e-05
# Cluster rate: 9.746134065089765e-05
# Cluster rate: 9.82197946637451e-05

# %%
plt.figure(figsize=(20,5)) # lets you make a custom size for your plot
plt.tick_params(labelsize=16) #adjust fontsize of axis ticks
plt.ylabel('# of Clusters',fontsize=16)
plt.xlabel('Unique channels',fontsize=16)

#array=plt.hist(get_channelspercluster(timeclusterdata), np.linspace(0,40,41), histtype='step')

array=plt.hist(data0.get_clusterdf()['Channels'], np.linspace(0,40,41), histtype='step', label='t=.1s')
array=plt.hist(data1.get_clusterdf()['Channels'], np.linspace(0,40,41), histtype='step', label='t=.5s')
array=plt.hist(data2.get_clusterdf()['Channels'], np.linspace(0,40,41), histtype='step', label='t=1s')
#array=plt.hist(data3.get_clusterdf()['Channels'], np.linspace(0,40,41), histtype='step', label='t=2s')


plt.legend(fontsize=16)
plt.gca().set_yscale("log")

# %%
#copy.deepcopy(data1).filter_clusterdf(2.5, 5)
array = plt.hist(data0.get_clusterdf()["TimeSpread"],np.linspace(0,10,50), histtype='step')
plt.title("Time Spread ()", fontsize=16)
plt.xlabel("Time Spread (s)", fontsize=14)
plt.ylabel("Occurance", fontsize=14)

#plt.savefig('plots/timespreads/Time_MaxPos.pdf',bbox_inches = "tight")
#plt.savefig('plots/timespreads/Time_MaxPos.png',dpi=300,bbox_inches = "tight")

plt.figure()
array = plt.hist(data1.get_clusterdf()["TimeSpread"],np.linspace(0,10,50), histtype='step')
plt.title("Time Spread ()", fontsize=16)
plt.xlabel("Time Spread (s)", fontsize=14)
plt.ylabel("Occurance", fontsize=14)


plt.figure()
array = plt.hist(data2.get_clusterdf()["TimeSpread"],np.linspace(0,10,50), histtype='step')
plt.title("Time Spread ()", fontsize=16)
plt.xlabel("Time Spread (s)", fontsize=14)
plt.ylabel("Occurance", fontsize=14)
# Out:
# Text(0, 0.5, 'Occurance')

# %%
print("Mean Timespread")

print("t=0.1: " + str(np.mean(data0.get_clusterdf()['TimeSpread'])))
print("t=0.5: " + str(np.mean(data1.get_clusterdf()['TimeSpread'])))
print("t=1.0: " + str(np.mean(data2.get_clusterdf()['TimeSpread'])))
# Out:
# Mean Timespread
# t=0.1: 0.7411877550958688
# t=0.5: 0.3151220364881547
# t=1.0: 0.17751351352069686

# %%
plt.figure(figsize=(20,5)) # lets you make a custom size for your plot
plt.tick_params(labelsize=16) #adjust fontsize of axis ticks
plt.title("Filtered NRMSE Distribution", fontsize=18)
plt.ylabel('# of Clusters',fontsize=16)
plt.xlabel('Normalized Root Mean Square Deviation',fontsize=16)

array=plt.hist(data0.clusterdf['NRMSE'], np.linspace(0,10,100), histtype='step')

line=plt.axvline(np.mean(data0.get_clusterdf()['NRMSE']))
#plt.gca().set_yscale("log")


plt.figure(figsize=(20,5)) # lets you make a custom size for your plot
plt.tick_params(labelsize=16) #adjust fontsize of axis ticks
plt.title("Filtered NRMSE Distribution", fontsize=18)
plt.ylabel('# of Clusters',fontsize=16)
plt.xlabel('Normalized Root Mean Square Deviation',fontsize=16)

#array=plt.hist(get_channelspercluster(timeclusterdata), np.linspace(0,40,41), histtype='step')

#array=plt.hist(clusterdata['Zenith(deg)'], np.linspace(0,180,181), histtype='step')
array=plt.hist(data1.clusterdf['NRMSE'], np.linspace(0,10,100), histtype='step')

line=plt.axvline(np.mean(data1.get_clusterdf()['NRMSE']))
#plt.gca().set_yscale("log")




plt.figure(figsize=(20,5)) # lets you make a custom size for your plot
plt.tick_params(labelsize=16) #adjust fontsize of axis ticks
plt.title("Filtered NRMSE Distribution", fontsize=18)
plt.ylabel('# of Clusters',fontsize=16)
plt.xlabel('Normalized Root Mean Square Deviation',fontsize=16)

#array=plt.hist(get_channelspercluster(timeclusterdata), np.linspace(0,40,41), histtype='step')

#array=plt.hist(clusterdata['Zenith(deg)'], np.linspace(0,180,181), histtype='step')
array=plt.hist(data2.clusterdf['NRMSE'], np.linspace(0,10,100), histtype='step')

line=plt.axvline(np.mean(data2.get_clusterdf()['NRMSE']))
#plt.gca().set_yscale("log")

# %%
print("Mean NRMSE")

print("t=0.1: " + str(np.mean(data0.get_clusterdf()['NRMSE'])))
print("t=0.5: " + str(np.mean(data1.get_clusterdf()['NRMSE'])))
print("t=1.0: " + str(np.mean(data2.get_clusterdf()['NRMSE'])))
# Out:
# Mean NRMSE
# t=0.1: 0.8626865774682616
# t=0.5: 0.8815399057744592
# t=1.0: 0.8916549093744615

# %%
plt.figure()
plt.title("Extra Channels (filtered)", fontsize=16)
plt.xlabel("Extra Channels in Cluster", fontsize=14)
plt.ylabel("Occurance", fontsize=14)

array = plt.hist(data0.get_clusterdf()['ExtraCh'], np.linspace(0,20,21))
plt.gca().set_yscale("log")


plt.figure()
plt.title("Extra Channels (filtered)", fontsize=16)
plt.xlabel("Extra Channels in Cluster", fontsize=14)
plt.ylabel("Occurance", fontsize=14)

array = plt.hist(data1.get_clusterdf()['ExtraCh'], np.linspace(0,20,21))
plt.gca().set_yscale("log")


plt.figure()
plt.title("Extra Channels (filtered)", fontsize=16)
plt.xlabel("Extra Channels in Cluster", fontsize=14)
plt.ylabel("Occurance", fontsize=14)

array = plt.hist(data2.get_clusterdf()['ExtraCh'], np.linspace(0,20,21))
plt.gca().set_yscale("log")

# %%
print("Average Extra Channels")
print("t=0.1: " + str(np.mean(data0.get_clusterdf()['ExtraCh'])))
print("t=0.5: " + str(np.mean(data1.get_clusterdf()['ExtraCh'])))
print("t=1.0: " + str(np.mean(data2.get_clusterdf()['ExtraCh'])))
# Out:
# Average Extra Channels
# t=0.1: 0.8040816326530612
# t=0.5: 0.8988326848249028
# t=1.0: 0.918918918918919

# %%
plt.figure()
plt.title("Missing Channels (filtered)", fontsize=16)
plt.xlabel("Missing Channels in Cluster", fontsize=14)
plt.ylabel("Occurance", fontsize=14)
array = plt.hist(data0.get_clusterdf()['MissingCh'], np.linspace(0,12,13))


plt.figure()
plt.title("Missing Channels (filtered)", fontsize=16)
plt.xlabel("Missing Channels in Cluster", fontsize=14)
plt.ylabel("Occurance", fontsize=14)
array = plt.hist(data1.get_clusterdf()['MissingCh'], np.linspace(0,12,13))


plt.figure()
plt.title("Missing Channels (filtered)", fontsize=16)
plt.xlabel("Missing Channels in Cluster", fontsize=14)
plt.ylabel("Occurance", fontsize=14)
array = plt.hist(data2.get_clusterdf()['MissingCh'], np.linspace(0,12,13))

# %%
print("Mean Missing Channels")

print("t=0.1: " + str(np.mean(data0.get_clusterdf()['MissingCh'])))
print("t=0.5: " + str(np.mean(data1.get_clusterdf()['MissingCh'])))
print("t=1.0: " + str(np.mean(data2.get_clusterdf()['MissingCh'])))
# Out:
# Mean Missing Channels
# t=0.1: 3.5428571428571427
# t=0.5: 3.5719844357976656
# t=1.0: 3.5984555984555984

# %%
data1.get_clusterdf()['data'] = 1
data1.get_clusterdf().head(20)
# Out:
#     Cluster  Events  Channels      StartTime  TimeSpread     NRMSE    Zenith  \
# 0         0       5         5    7194.280633    0.071746  0.587038  0.405188
# 1         1       5         5   37039.568918    0.233769  0.898893  0.743109
# 2         2       9         9   42896.794037    0.664183  0.840447  0.770941
# 3         3       5         5   62388.304316    0.079678  0.697575  0.770401
# 4         4       5         5   73675.806707    0.217087  0.603066  0.426780
# 5         5       5         5   76696.362773    0.079698  0.714815  0.644002
# 6         6       8         8   88352.220389    0.055182  0.544042  0.671172
# 9         9      11         7   90228.217414    2.265780  1.459444  0.278755
# 10       10       6         6   90236.208487    0.643498  2.467221  1.529754
# 12       12       5         5   94229.723523    0.331832  1.847424  0.833785
# 13       13       8         8   94865.713248    0.303666  1.174773  0.427517
# ...

# %%
data2.get_clusterdf()['data'] = 2
data2.get_clusterdf().head(20)
# Out:
#     Cluster  Events  Channels   StartTime  TimeSpread     NRMSE    Zenith  \
# 0         0       5         5    7191.128       0.024  0.587038  0.405188
# 1         1       5         5   37036.432       0.064  0.898893  0.743109
# 2         2       9         9   42893.584       0.680  0.840447  0.770941
# 3         3       5         5   62385.168       0.024  0.697575  0.770401
# 4         4       5         5   73672.640       0.040  0.603066  0.426780
# 5         5       5         5   76693.208       0.048  0.714815  0.644002
# 6         6       8         8   88349.064       0.032  0.544042  0.671172
# 9         9       5         5   90225.136       0.104  1.786154  0.128567
# 10       10       6         6   90226.288       1.008  1.441800  0.371530
# 11       11       6         6   90233.032       0.640  2.467221  1.529754
# 13       13       5         5   94226.592       0.072  1.847424  0.833785
# 14       14       8         8   94862.576       0.040  1.174773  0.427517
# ...

# %%
unique = pd.concat([data2.get_clusterdf(),data3.get_clusterdf()])
unique.drop_duplicates(keep=False, subset=unique.columns.difference(['Cluster', 'data'])).sort_values(by=['StartTime'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-34a573c286e3> in <module>
# ----> 1 unique = pd.concat([data2.get_clusterdf(),data3.get_clusterdf()])
#       2 unique.drop_duplicates(keep=False, subset=unique.columns.difference(['Cluster', 'data'])).sort_values(by=['StartTime'])
#
# NameError: name 'data3' is not defined

# %%
data3.show_cluster(36)

# %%
data1.show_cluster(31)
data2.show_cluster(30)
