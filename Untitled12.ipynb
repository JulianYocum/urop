# %%
from MonteCarlo import MonteCarlo

# %%
mc = MonteCarlo(100, 'sasso')

# %%
mc.get_clusterdf()
# Out:
#     Cluster  Events  Channels     StartTime  TimeSpread     NRMSE    Zenith  \
# 0         0       1         1  4.344399e+03         0.0  0.000000  0.419659
# 1         1       5         5  5.475169e+03         0.0  1.124989  0.492910
# 2         2       2         2  1.133188e+04         0.0  0.000000  0.932366
# 3         3       7         7  6.510525e+04         0.0  1.094812  0.876713
# 4         4       9         9  8.902683e+04         0.0  0.993809  0.678532
# ..      ...     ...       ...           ...         ...       ...       ...
# 84       84       6         6  1.013534e+06         0.0  1.057840  0.960321
# 85       85      14        14  1.041042e+06         0.0  0.824900  0.728324
# 86       86      11        11  1.053781e+06         0.0  0.898971  0.466333
# 87       87      12        12  1.059672e+06         0.0  1.057573  0.567580
# 88       88      10        10  1.086827e+06         0.0  0.907914  0.840872
#
#      Azimuth  ExtraCh  MissingCh  \
# ...

# %%
mc.show_cluster(1)
