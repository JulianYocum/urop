# %%
import matplotlib.pyplot as plt
import numpy as np


# %run DataAnalysis.ipynb

# %%
data = DataAnalysis()

# %%
data.eventsperchannel()[86]
# Out:
# 70344

# %%
plt.figure(figsize=(12,5))
plt.bar(range(988), data.eventsperchannel())
plt.ylim(0,1000)
# Out:
# (0.0, 1000.0)

# %%
plt.figure(figsize=(15,5)) # lets you make a custom size for your plot
array = plt.hist(data.get_eventdf()['Channel'].values, np.linspace(0,989,990) ,histtype='step' )
plt.ylim(1,1000)
# Out:
# (1.0, 1000.0)

# %%
data.noisychannels()
# Out:
# [87,
#  361,
#  363,
#  364,
#  557,
#  558,
#  559,
#  570,
#  611,
#  713,
#  714,
#  715,
#  936,
#  973,
#  974,
#  975,
#  988]

# %%
array[0][87]
# Out:
# 70344.0

# %%
alldata.get_clusterdf().tail(20)
# Out:
#      Cluster  Events  Channels    StartTime  TimeSpread         NRMSE  \
# 263      263       5         5  2546361.441       0.848  5.440276e-01
# 264      264       6         6  2561422.300       0.461  9.475103e-01
# 265      265       6         6  2567249.490       0.793  8.375750e-01
# 266      266       5         5  2580532.070       0.045  4.765338e-01
# 267      267       6         6  2586678.918       0.716  7.409824e-01
# 268      268      11        11  2620039.038       1.439  2.337754e+00
# 269      269       5         2  2620041.896       0.887  0.000000e+00
# 270      270       6         5  2638456.565       0.128  9.943723e-01
# 271      271       5         5  2657215.617       0.764  0.000000e+00
# 272      272       5         5  2674445.705       0.553  6.462918e-01
# 273      273       5         5  2676968.565       0.330  7.965181e-01
# 274      274       7         7  2686329.148       0.795  7.169606e-01
# ...

# %%
array = plt.hist(alldata.get_clusterdf()['ExtraCh'], np.linspace(1,50,50))

#plt.gca().set_yscale("log")

# %%
array = plt.hist(alldata.get_clusterdf()['MissingCh'])
#plt.gca().set_yscale("log")

# %%
data = alldata.get_clusterdf()['MissingCh'] / (alldata.get_clusterdf()['Channels'] + alldata.get_clusterdf()['MissingCh'] - alldata.get_clusterdf()['ExtraCh'])

# %%
array = plt.hist(data)

# %%
alldata.show_clusters([6,15,37,41,66, 68], 45, 45)

# %%
math.atan2(10,.01)
# Out:
# 1.5697963271282298

# %%
clusternum = 276

# %%
import matplotlib.pyplot as plt

linepoints = alldata.get_fitline(alldata.get_cluster(clusternum))
hit_channels = alldata.get_channelcollisions(linepoints)
coords = alldata.load_coords()

hit_channel_coords = np.array([coords[channel] for channel in hit_channels])


plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
#ax.set_proj_type('ortho')

ax.scatter3D(*hit_channel_coords.T)
ax.plot3D(*linepoints.T)

plt.xlim([-350,350])
plt.ylim([-350,350])
ax.set_zlim([-350,350])

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.view_init(20, 130)

plt.show()

# %%
alldata.show_cluster(clusternum, 20, 130)
